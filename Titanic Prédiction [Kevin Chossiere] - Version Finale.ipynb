# %% [markdown]
# # Analyse exploratoire et modèle prédictif - Etude de cas du Titanic

# %% [markdown]
# ## Etape 1 - Data Understanding

# %% [markdown]
# “Le transatlantique Titanic, le plus grand paquebot du monde, appartenant à la compagnie anglaise The White Star Line, a heurté la nuit dernière contre un iceberg, près des bancs de Terre-Neuve, et a coulé. Fort heureusement, les secours ont été prompts, et les passagers, au nombre de 2700, y compris l'équipage, ont pu être tous sauvés.”
# C’est ce que nous pouvions lire le 16 avril 1912 dans l’Echo de Paris, mais aurions-nous pu prédire qui allait survivre ? C’est ce à quoi nous allons tenter de répondre à travers cette analyse.
#
# Pour cela nous allons :
# - Analyser et identifier les facteurs favorisant la survie
# - Mettre en place un modèle de prédiction permettant de déterminer qui survivra sur nos données de test

# %% [markdown]
# ### Import des libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install xgboost
# %matplotlib inline

from collections import Counter

from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_score
from sklearn.model_selection import cross_validate, learning_curve
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_curve, precision_recall_curve, auc, make_scorer, confusion_matrix, f1_score, fbeta_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelBinarizer

# Importation des classifieurs Naive Bayes, régression logistique, Bagging, RandomForest, AdaBoost, GradientBoost, arbres de décision, SVM et XGBoost
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier

# On va définir ici le style de tracé (graphique)
plt.style.use('seaborn-notebook')
from matplotlib.ticker import StrMethodFormatter

sns.set(style='white', context='notebook', palette='deep')
# Out:
# Requirement already satisfied: xgboost in c:\users\kcho\anaconda3\lib\site-packages (1.7.5)
# Requirement already satisfied: numpy in c:\users\kcho\anaconda3\lib\site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in c:\users\kcho\anaconda3\lib\site-packages (from xgboost) (1.9.1)

# %% [markdown]
# ### Lecture des données d'entraînement et de test

# %%
# Ici nous allons chercher à nous connecter à nos données en indiquant notre répertoire
train = pd.read_csv("C:/Users/kcho/Desktop/Titanic/train.csv")
test = pd.read_csv("C:/Users/kcho/Desktop/Titanic/test.csv")
IDtest = test["PassengerId"]

# %% [markdown]
# Pour réaliser cette étude de cas nous allons utiliser la méthode CRISP-DM c'est à dire :

# %% [markdown]
# ## Etape 2 : Data Understanding

# %% [markdown]
# ### Description du dataset 'train'

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Cet aperçu nous permet de mieux comprendre les différentes composantes de notre dataset et d’amener nos premières pistes de réflexions. Voici un résumé pour chacune des colonnes :
#
# - PassengerId : Numéro d'identification unique d'un passager
# - Survival : le passager a survécu ou non ; 1 s'il a survécu et 0 s'il n'a pas survécu.
# - Pclass : Classe du ticket (1= première classe, 2= seconde classe,3= troisième classe). Peut être considéré comme un élément permettant d’évaluer le statut socio-économique de l’individu.
# - Sex : sexe
# - Age : âge en années
# - Sibsp : Nombre de frères et sœurs / conjoints à bord du Titanic
# - Parch : Nombre de parents / enfants à bord du Titanic
# - Ticket : Numéro du ticket
# - Fare : Tarif passager
# - Cabin : Numéro de la cabine
# - Embarked : Port d'embarquement (C = Cherbourg, Q = Queenstown, S = Southampton)
#
# On peut les regrouper en fonction de la typologie de variables auxquelles elles appartiennent :
#
# - Variables catégorielles :
#
#     - Nominales (variables ayant deux catégories ou plus, mais qui n'ont pas d'ordre intrinsèque)
#         Cabin
#         Embarked (Port d'embarquement : C (Cherbourg),Q (Queenstown), S (Southampton)
#
#     - Dichotomiques (variable nominale avec seulement deux catégories)
#         Sex (Homme/Femme)
#
# - Ordinales (variables ayant deux catégories ou plus, tout comme les variables nominales. Seules les catégories peuvent également être ordonnées ou classées.)
#     - Pclass (statut socio-économique : 1 (Première classe, classe premium), 2 (Seconde classe), 3 (Troisème classe)
# - Variables numériques :
#     - Discrètes
#         PassengerID(identifiant unique pour chaque passager)
#         SibSp
#         Parch
#         Survived (notre résultat ou variable dépendante : 0 ou 1)
#
# - Continues
#     Age
#     Fare
#
# - Variables textuelles :
#     Ticket (numéro de billet pour le passager)
#     Name (nom du passager)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.shape
# Out:
# (891, 12)

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Description du dataset 'test'

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
test.shape
# Out:
# (418, 11)

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# Les tableaux ci-dessus nous permettent de constater certaines choses :
# - Nous avons quelques variables catégorielles qui doivent être converties en données numériques afin que les algorithmes d'apprentissage automatique puissent les traiter.
# - Les features ont des échelles très différentes et nous devrons les convertir à peu près à la même échelle.
# - Certaines features contiennent des valeurs manquantes (NaN = Not a Number), que nous devons traiter.

# %% [markdown]
# ## Identification des outliners et traitement des valeurs manquantes

# %% [markdown]
#  Nous allons donc tenter d'approfondir nos analyses concernant les données à notre disposition pour tenter d'identifier :
#  - Les valeurs aberrantes/outliers
#  - Les doublons
#  - Les valeurs manquantes
#
# Une fois cela fait il sera possible de déterminer comment les traiter.

# %% [markdown]
# ### Les valeurs manquantes

# %%
print (train.isnull().sum())
print (''.center(20, "*"))
print (test.isnull().sum())
sns.boxplot(x='Survived',y='Fare',data=train)
missing_values=train.isnull().sum() 
missing_values[missing_values>0]/len(train)*100
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# ********************
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64
# Age         19.865320
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64

# %% [markdown]
# Ici on s'aperçoit que les colonnes 'Age', 'Cabin' et 'Embarked' ont des valeurs manquantes. Pour le dataset de train on constate 19,87% de valeurs manquantes pour l'âge, 77,10% pour le numéro de la Cabine et 0,2% de valeurs manquantes pour le point d'embarquement.
#
# Les données manquantes dans l'ensemble de données d'entraînement peuvent réduire l'ajustement d'un modèle ou conduire à un modèle biaisé car nous n'avons pas correctement analysé le comportement et la relation avec d'autres variables. Cela peut conduire à des prédictions ou classifications erronées. Pour éviter cette problématique il est nécessaire de traiter ces valeurs manquantes en prennant en compte le contexte.

# %% [markdown]
# ### Identification des outliers pour les variables numériques

# %% [markdown]
# J'ai voulu utiliser la méthode de Tukey pour identifier des outliers. Cependant la méthode de Tukey est opérationnelle lorsque nous sommes en proie à une distribution qui n'est pas normale. Nous allons donc commencer par afficher la distribution pour les variables numériques "Age", "SibSp", "Parch", et "Fare" afin de vérifier qu'elles ne répondent pas à une distribution normale.

# %%
import matplotlib.pyplot as plt

for col in ["Age", "SibSp", "Parch", "Fare"]:
    plt.hist(train[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# Afficher les histogrammes pour les variables numériques peut nous permettre de déterminer la direction dans laquelle ces variables sont distribuées, les valeurs aberrantes apparaîtront en dehors de la distribution globale des données. Si l'histogramme est asymétrique à droite ou à gauche, cela indique la présence de valeurs extrêmes ou de valeurs aberrantes. Ici nous pouvons donc déduire que certaines valeurs sont aberrantes (excepté pour l'age). L'âge n'est pas un problème car même avec une valeur min à 0,17 on peut très bien en déduire qu'il s'agit d'un bébé. Pour traiter les valeurs aberrantes on peut réaliser la méthode de Tukey cependant il faut vérifier que la distribution n'est pas normale c'est le but de l'étape suivante.

# %%
from scipy.stats import shapiro
import pandas as pd

# spécifier les colonnes à tester
cols_to_test = ["Survived", "PassengerId", "Pclass", "Age", "SibSp", "Parch", "Fare"]

# effectuer le test de Shapiro-Wilk sur chaque colonne
for col in cols_to_test:
    # extraire la colonne du dataframe
    data = train[col]

    # effectuer le test de Shapiro-Wilk sur la colonne
    stat, p = shapiro(data)

    # afficher le résultat du test
    print("Colonne : ", col)
    print("Statistiques du test de Shapiro-Wilk : ", stat)
    print("p-value : ", p)

    # interpréter le résultat du test
    alpha = 0.05
    if p > alpha:
        print("La distribution des données est normale (on ne peut pas rejeter H0)")
    else:
        print("La distribution des données n'est pas normale (on rejette H0)")
# Out:
# Colonne :  Survived
# Statistiques du test de Shapiro-Wilk :  0.616659939289093
# p-value :  1.7945308393836472e-40
# La distribution des données n'est pas normale (on rejette H0)
# Colonne :  PassengerId
# Statistiques du test de Shapiro-Wilk :  0.9547972679138184
# p-value :  6.309874531781976e-16
# La distribution des données n'est pas normale (on rejette H0)
# Colonne :  Pclass
# Statistiques du test de Shapiro-Wilk :  0.718337893486023
# p-value :  3.3958319924210316e-36
# La distribution des données n'est pas normale (on rejette H0)
# Colonne :  Age
# Statistiques du test de Shapiro-Wilk :  nan
# p-value :  1.0
# La distribution des données est normale (on ne peut pas rejeter H0)
# Colonne :  SibSp
# Statistiques du test de Shapiro-Wilk :  0.5129655003547668
# p-value :  5.74532370373175e-44
# La distribution des données n'est pas normale (on rejette H0)
# Colonne :  Parch
# Statistiques du test de Shapiro-Wilk :  0.5328145027160645
# p-value :  2.382207389352189e-43
# La distribution des données n'est pas normale (on rejette H0)
# Colonne :  Fare
# Statistiques du test de Shapiro-Wilk :  0.5218917727470398
# p-value :  1.0789998175301091e-43
# La distribution des données n'est pas normale (on rejette H0)

# %% [markdown]
# On constate donc que les différentes distributions des variables que nous avions identifiés ne sont pas normales. Nous pouvons donc utiliser la méthode de Tukey pour identifier les outliers.

# %%
# Détection des outliers

def detect_outliers(df,n,features):
    outlier_indices = []
    
    # Iterer sur chacune des colonnes du dataset
    for col in features:
        # Premier quartile (25%)
        Q1 = np.percentile(df[col], 25)
        # Troisème quartile (75%)
        Q3 = np.percentile(df[col],75)
        # Intervalle interquartile (le fameux IQR)
        IQR = Q3 - Q1
        
        # Niveau de la valeur aberrante que je fixe selon Turkey
        outlier_step = 1.5 * IQR
        
        # Déterminer une liste d'indices de valeurs aberrantes pour col
        outlier_list_col = df[(df[col] < Q1 - outlier_step) | (df[col] > Q3 + outlier_step )].index
        
        # Ajouter les indices de valeurs aberrantes trouvés pour col à la liste des indices de valeurs aberrantes
        outlier_indices.extend(outlier_list_col)
        
    # Sélectionner les observations contenant plus de 2 valeurs aberrantes
    outlier_indices = Counter(outlier_indices)        
    multiple_outliers = list( k for k, v in outlier_indices.items() if v > n )
    
    return multiple_outliers   

# Détection des outliers des colonnes Age, SibSp , Parch and Fare : uniquement pour les valeurs numériques
Outliers_to_drop = detect_outliers(train,2,["Age","SibSp","Parch","Fare"])

# %%
train.loc[Outliers_to_drop] # On va afficher les outliers
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 27            28         0       1     Fortune, Mr. Charles Alexander    male
# 88            89         1       1         Fortune, Miss. Mabel Helen  female
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 341          342         1       1     Fortune, Miss. Alice Elizabeth  female
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket    Fare        Cabin Embarked
# 27   19.0      3      2     19950  263.00  C23 C25 C27        S
# 88   23.0      3      2     19950  263.00  C23 C25 C27        S
# 159   NaN      8      2  CA. 2343   69.55          NaN        S
# 180   NaN      8      2  CA. 2343   69.55          NaN        S
# 201   NaN      8      2  CA. 2343   69.55          NaN        S
# 324   NaN      8      2  CA. 2343   69.55          NaN        S
# 341  24.0      3      2     19950  263.00  C23 C25 C27        S
# 792   NaN      8      2  CA. 2343   69.55          NaN        S
# 846   NaN      8      2  CA. 2343   69.55          NaN        S
# 863   NaN      8      2  CA. 2343   69.55          NaN        S

# %% [markdown]
# Après quelques recherches sur internet concernant les informations sur le prix des billets que l'on aurait pu croire comme aberrantes avec une valeur de 512 (valeur max) sont finalement plausibles car certains voyageurs prennaient des appartements en plus etc... Nous détectons tout de même 10 valeurs aberrantes. Les 28, 89 et 342 passagers ont un 'Fare' élevé par rapport aux quartiles. Les 7 autres ont des valeurs très élevées de SibSP. Nous pouvons donc supprimer ces outliers, c'est le rôle de la ligne suivante.

# %%
# Suppression des outliers
train = train.drop(Outliers_to_drop, axis = 0).reset_index(drop=True)

# %% [markdown]
# ### Identification des doublons

# %% [markdown]
# Une fois les outliers identifiées nous pouvons passer aux doublons. La ligne de code ci-dessous va nous permettre de compter les enregistrements en double.

# %%
# Trouver le nombre d'enregistrements en doublon
print('train - Nombre denregistrements en double:', train.duplicated().sum())
print('test - Nombre denregistrements en double:', test.duplicated().sum())
# Out:
# train - Nombre denregistrements en double: 0
# test - Nombre denregistrements en double: 0

# %% [markdown]
# Dans notre cas on constate l'absence de doublons ce qui est plutôt positif pour nous car aucun retraitement ne sera à effectuer.

# %% [markdown]
# ### Traitement des valeurs manquantes

# %% [markdown]
# Une des étapes les plus délicates pour permettre à notre modèle d'avoir une bonne fiabilité ainsi que pour mener une analyse exploratoire digne de ce nom correspond au traitement des valeurs manquantes. Un mauvais traitement dans les valeurs manquantes (sans prise en compte du contexte) amènera à des données biaisées et à un manque de fiabilité de notre modèle. Nous allons faire en sorte de prendre en maximum le contexte des données pour déterminer comment traiter ces données manquantes.

# %% [markdown]
# #### Traitement des valeurs manquantes pour l'Age

# %% [markdown]
# Nous avons dans les premières lignes de l'exploration de notre jeu de données constatés que l'age possèdaient de nombreuses lignes avec des valeurs manquantes. Il existe plusieurs manières de traiter ces lignes vides, la plus courante étant de calculer la moyenne d'âge et de l'imputer aux lignes manquantes. Cependant, on constate ici une diversité dans les profils de notre base de données. Si bien que j'ai décidé d'utiliser le titre présent dans le nom pour déterminer l'age de la ligne. Je m'explique, au lieu de calculer la moyenne sur toute la base de données je vais calculer la moyenne des âges des personnes possédants le même titre que la personne dont l'age est manquant. Ainsi nous gagnons en fiabilité, il est rare d'avoir un titre de 'Capt' lorsque l'on a 4 ans. Je suis donc parti du principe qu'il était de même pour les autres titres.

# %%
# Comme le test n'a qu'une seule valeur manquante, remplissons-la avec la moyenne.
test['Fare'].fillna(test['Fare'].mean(), inplace=True)

# Concatenation des données d'entrainement et de test pour le traitement
data_df = pd.concat([train, test], ignore_index=True)

# Extraction des titres à partir des noms des passagers
data_df['Title'] = data_df['Name'].str.extract(' ([A-Za-z]+)\.', expand=True)

# Remplacement des titres rares par les plus courants
mapping = {'Mlle': 'Miss', 'Major': 'Mr', 'Col': 'Mr', 'Sir': 'Mr', 'Don': 'Mr', 'Mme': 'Miss',
           'Jonkheer': 'Mr', 'Lady': 'Mrs', 'Capt': 'Mr', 'Countess': 'Mrs', 'Ms': 'Miss', 'Dona': 'Mrs'}
data_df.replace({'Title': mapping}, inplace=True)

# Affichage des différents titres et leur nombre d'occurrences
print(data_df['Title'].value_counts())

# Imputation de l'âge manquant en utilisant la moyenne de l'âge par titre
titles = ['Mr', 'Miss', 'Mrs', 'Master', 'Rev', 'Dr']
for title in titles:
    age_to_impute = data_df.groupby('Title')['Age'].mean()[title]
    data_df.loc[(data_df['Age'].isnull()) & (data_df['Title'] == title), 'Age'] = age_to_impute

# Séparation des données d'entrainement et de test mises à jour
train = data_df.iloc[:len(train)]
test = data_df.iloc[len(train):]

# Vérification du nombre de valeurs nulles dans les données d'entrainement et de test
print(train.isnull().sum())
print(test.isnull().sum())
# Out:
# Mr        763
# Miss      260
# Mrs       200
# Master     60
# Rev         8
# Dr          8
# Name: Title, dtype: int64
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          680
# Embarked         2
# Title            0
# dtype: int64
# PassengerId      0
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# Title            0
# dtype: int64

# %% [markdown]
# Nous voilà avec un traitement des données manquantes pour l'âge :

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title
# 0      0         A/5 21171   7.2500   NaN        S    Mr
# 1      0          PC 17599  71.2833   C85        C   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 3      0            113803  53.1000  C123        S   Mrs
# 4      0            373450   8.0500   NaN        S    Mr

# %% [markdown]
# #### Traitement des valeurs manquantes pour le numéro de Cabine et suppresion de la colonne 'Ticket'

# %% [markdown]
# Au vue du nombre de données manquantes qui correspondent à 77% des données totales il est préférable de supprimer cette colonne. De plus, le numéro de cabine est difficilement exploitable en l'état car a une partie numérique et alphabétique. Par la même occasion nous allons supprimer la colonne 'Ticket' qui n'a aucune valeur dans notre analyse

# %%
print("Avant", train.shape, test.shape)

train = train.drop(['Ticket', 'Cabin'], axis=1)
test = test.drop(['Ticket', 'Cabin'], axis=1)

("Après", train.shape, test.shape)
# Out:
# Avant (881, 13) (418, 13)
# ('Après', (881, 11), (418, 11))

# %% [markdown]
# #### Traitement du sexe en changeant la catégorie

# %% [markdown]
# Afin de faciliter l'exploitation de nos données concernant le sexe ainsi que le traitement de notre modèle il est préférable de modifier le type de cette variable. De base, nous avions des chaines de caractère. Nous allons donc attribuer une valeur à chacun des 2 sexes (0 pour l'homme, 1 pour la femme).

# %%
# Mapper chaque valeur de la variable "Sexe" à une valeur numérique
sex_mapping = {"male": 0, "female": 1}
train['Sex'] = train['Sex'].map(sex_mapping)
test['Sex'] = test['Sex'].map(sex_mapping)

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#       Fare Embarked Title
# 0   7.2500        S    Mr
# 1  71.2833        C   Mrs
# 2   7.9250        S  Miss
# 3  53.1000        S   Mrs
# 4   8.0500        S    Mr

# %% [markdown]
# #### Traitement des valeurs du port d'embarquement

# %% [markdown]
# Pour traiter le faible nombre de valeurs manquantes pour le port d'embarquement j'ai décidé de remplacer les valeurs manquantes par la valeur la plus récurrente. La première ligne va nous permettre de déterminer la valeur la plus récurrente et la deuxième ligne complétera les valeurs manquantes du port d'embarquement en attribuant cette valeur.

# %%
freq_port = train.Embarked.dropna().mode()[0]
freq_port
# Out:
# 'S'

# %%
for dataset in [train, test]:
    dataset['Embarked'] = dataset['Embarked'].fillna(freq_port)

train[['Embarked', 'Survived']].groupby(['Embarked'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.341195

# %% [markdown]
# ### Analyse des résultats et interprétation

# %% [markdown]
# Cette partie va nous permettre d'identifier des liens entre les variables et notre chance de survie. J'ai commencé par faire une heatmap permettant d'identifier les facteurs corrélés à notre survie. Cette heatmap servira de base à nos hypothèses et de pistes à explorer.

# %%
heatmap = sns.heatmap(train.corr()[['Survived']].sort_values(by='Survived', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with Survived', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# ##### Hypothèse 1 : Combien de personnes ont embarqué depuis différents ports ? Y a-t-il une corrélation entre le port d'embarquement et la survie ?

# %%
train['Embarked'].value_counts()/len(train)
# Out:
# S    0.721907
# C    0.190692
# Q    0.087401
# Name: Embarked, dtype: float64

# %%
sns.set(style="darkgrid")
sns.countplot( x='Embarked', data=train, hue="Embarked", palette="Set1");

# %% [markdown]
# On constate qu'il y a une forte proportion des voyageurs qui ont embarqués par le port de Southampton.

# %%
sns.set(style="darkgrid")
sns.countplot( x='Survived', data=train, hue="Embarked", palette="Set1");

# %%
train.groupby('Embarked').mean()
# Out:
#           PassengerId  Survived    Pclass       Sex        Age     SibSp  \
# Embarked
# C          445.357143  0.553571  1.886905  0.434524  31.005678  0.386905
# Q          417.896104  0.389610  2.909091  0.467532  27.794655  0.428571
# S          450.561321  0.341195  2.345912  0.314465  29.843663  0.476415
#
#              Parch       Fare
# Embarked
# C         0.363095  59.954144
# Q         0.168831  13.276030
# S         0.386792  25.665957

# %% [markdown]
# Cependant on remarque que l'espérance de vie est meilleure pour les voyageurs ayant embarqués sur le port de Cherbourg. Après quelques recherches sur internet cette espérance peut être expliquée par un autre facteur : le niveau de vie. En effet, les habitants de Cherbourg ont un meilleur niveau de vie que les habitants des 2 autres ports, cela implique également un investissement plus important dans l'achat de billet et donc sûrement une classe plus importante. Cette hypothèse est également confirmée par le prix du billet que l'on constate à 59,95 vs 13 et 25.

# %% [markdown]
# #####  Q2: Est-ce que la survie dépend du sexe ?

# %%
train.groupby('Sex').mean()
# Out:
#      PassengerId  Survived    Pclass        Age     SibSp     Parch       Fare
# Sex
# 0     455.386364  0.190559  2.388112  31.015567  0.372378  0.220280  24.800851
# 1     430.660194  0.747573  2.158576  27.795493  0.608414  0.627832  42.822048

# %% [markdown]
# Le résultat est sans équivoque. Le cas du titanic est l'exemple parfait du dicton "les femmes et les enfants d'abord". Avec 75% de survie constatée chez les femmes le résultat est sans appel. Cependant, il est possible de vérifier si ces résultats ne peuvnet pas être croisés avec d'autres données.

# %%
FacetGrid = sns.FacetGrid(train, row='Embarked', size=4.5, aspect=1.6)
FacetGrid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', order=None, hue_order=None )
FacetGrid.add_legend();
# Out:
# C:\Users\kcho\Anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Il semble y avoir une corrélation entre le port d'embarquement et la survie, selon le sexe des passagers. Les femmes qui ont embarqué au port Q et au port S ont une plus grande chance de survie. C'est le contraire si elles ont embarqué au port C. Les hommes ont une probabilité de survie élevée s'ils ont embarqué au port C, mais une faible probabilité s'ils ont embarqué au port Q ou S. Le niveau de la classe de voyage (Pclass) est également corrélé à la survie.

# %%
train[["Sex","Survived"]].groupby('Sex').mean()
# Out:
#      Survived
# Sex
# 0    0.190559
# 1    0.747573

# %%
survived = 'survived'
not_survived = 'not survived'
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(16, 8))
femme = train[train['Sex']==1]
homme = train[train['Sex']==0]
ax = sns.distplot(femme[femme['Survived']==1].Age.dropna(), bins=18, label = survived, ax = axes[0], kde =False, color="green")
ax = sns.distplot(femme[femme['Survived']==0].Age.dropna(), bins=40, label = not_survived, ax = axes[0], kde =False, color="red")
ax.legend()
ax.set_title('Femme')
ax = sns.distplot(homme[homme['Survived']==1].Age.dropna(), bins=18, label = survived, ax = axes[1], kde = False, color="green")
ax = sns.distplot(homme[homme['Survived']==0].Age.dropna(), bins=40, label = not_survived, ax = axes[1], kde = False, color="red")
ax.legend()
_ = ax.set_title('Homme');
# Out:
# C:\Users\kcho\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# On peut voir que les hommes ont une forte probabilité de survie quand ils ont entre 18 et 30 ans, ce qui est également un peu vrai pour les femmes mais pas complètement. Pour les femmes, les chances de survie sont plus élevées entre 14 et 40 ans. Sachant que les femmes ont généralement une plus forte probabilité de survie.
# Pour les hommes, la probabilité de survie est très élevé pour les bébés/nourrissons et pour les jeunes hommes mais c'est également le cas pour les femmes.

# %% [markdown]
# #### Q3 : Est-ce que la classe détermine la probabilité de survie ?

# %%
sns.barplot(x='Pclass', y='Survived', data=train);

# %%
#draw a bar plot of survival by Pclass
sns.barplot(x="Pclass", y="Survived", data=train)

#print percentage of people by Pclass that survived
print("Pourcentage de la première classe qui ont survécu:", train["Survived"][train["Pclass"] == 1].value_counts(normalize = True)[1]*100)

print("Pourcentage de la deuxième classe qui ont survécu", train["Survived"][train["Pclass"] == 2].value_counts(normalize = True)[1]*100)

print("Pourcentage de la troisième classe qui ont survécu", train["Survived"][train["Pclass"] == 3].value_counts(normalize = True)[1]*100)
# Out:
# Pourcentage de la première classe qui ont survécu: 62.91079812206573
# Pourcentage de la deuxième classe qui ont survécu 47.28260869565217
# Pourcentage de la troisième classe qui ont survécu 24.586776859504134

# %%
g = sns.factorplot(x="Pclass", y="Survived", hue="Sex", data=train,
                   size=6, kind="bar", palette="muted")
g.despine(left=True)
new_labels = ['Homme', 'Femme']
for t, l in zip(g._legend.texts, new_labels): t.set_text(l)
g = g.set_ylabels("survival probability")
# Out:
# C:\Users\kcho\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\kcho\Anaconda3\lib\site-packages\seaborn\categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
grid = sns.FacetGrid(train, col='Survived', row='Pclass', size=3.2, aspect=1.6)
grid.map(plt.hist, 'Age', alpha=.5, bins=20)
grid.add_legend();
# Out:
# C:\Users\kcho\Anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Ici, nous constatons clairement que la classe (Pclass) a une influence sur les chances de survie d'une personne, en particulier si cette personne est en première classe (1).
# Le graphique ci-dessus confirme notre hypothèse sur la classe 1, mais nous pouvons également constater une forte probabilité qu'une personne en classe 3 ne survivra pas.

# %% [markdown]
# #### Q4 : Est-ce que le prix du billet détermine la probabilité de survivre ?

# %%
# grid = sns.FacetGrid(train_df, col='Embarked', hue='Survived', palette={0: 'k', 1: 'w'})
grid = sns.FacetGrid(train, row='Embarked', col='Survived', size=2.2, aspect=1.6)
grid.map(sns.barplot, 'Sex', 'Fare', alpha=.5, ci=None)
grid.add_legend()
# Out:
# C:\Users\kcho\Anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\kcho\Anaconda3\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# Nous constatons donc que oui, le prix du billet influence bien les chances de survie puisque les tarifs les plus élevés sont ceux qui ont survécu peu importe le port d'embarquement.

# %% [markdown]
# #### Q5 - Est-ce que le titre donne une meilleure chance de survie ?

# %%
train[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0      Dr  0.428571
# 1  Master  0.589744
# 2    Miss  0.712707
# 3      Mr  0.161228
# 4     Mrs  0.795276
# 5     Rev  0.000000

# %% [markdown]
# En effet, on constate que le titre a également son rôle a joué. Mais davantage car il est lié au sexe ou au niveau de vie de l'individu qui le porte.

# %% [markdown]
# #### Q6 : Les passagers qui voyagent seuls ont-ils de meilleures chances de survie ?

# %% [markdown]
# SibSp et Parch auraient plus de sens en tant que features combinée, qui montre le nombre total de parents qu'une personne a sur le Titanic. Je vais la créer ci-dessous ainsi qu'une fonctionnalité qui montre si quelqu'un est seul ou non.

# %%
data = [train, test]
for dataset in data:
    dataset['relatives'] = dataset['SibSp'] + dataset['Parch']
    dataset.loc[dataset['relatives'] > 0, 'voyageur_seul'] = 'Non'
    dataset.loc[dataset['relatives'] == 0, 'voyageur_seul'] = 'Oui'
train['voyageur_seul'].value_counts()
# Out:
# Oui    537
# Non    344
# Name: voyageur_seul, dtype: int64

# %%
train['relatives'].value_counts()
# Out:
# 0    537
# 1    161
# 2    102
# 3     29
# 5     19
# 4     15
# 6     12
# 7      6
# Name: relatives, dtype: int64

# %%
sns.barplot(x='voyageur_seul', y='Survived', data=train);

# %%
sns.barplot(x='SibSp', y='Survived', data=train);

# %%
sns.barplot(x='Parch', y='Survived', data=train);

# %%
axes = sns.factorplot('relatives','Survived', 
                      data=train, aspect = 2.5, );
# Out:
# C:\Users\kcho\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\kcho\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# On peut constater ici que l'on a une probabilité de survie élevée avec 1 à 3 personnes, mais une probabilité plus faible si on a moins de 1 ou plus de 3 personnes avec nous (sauf pour certains cas avec 6 personnes apparentées). Donc non, il était préférable pour vous de ne pas être seul lorsque le titanic a coulé.

# %%
# Matrice de corrélation entre les valeurs numériques (SibSp, Parch, Age, Fare, Title, Pclass) et Survived.
g = sns.heatmap(train[["Survived","SibSp","Parch","Age","Fare","Pclass","voyageur_seul", "Title"]].corr(),annot=True, fmt = ".2f", cmap = "coolwarm")

# %% [markdown]
# L'avantage de cette matrice corrélation est qu'il est facile d'interpréter nos résultats et qu'elle permet de récapituler les différents constats que nous avons pu établir au préalable.
# A savoir l'impact de :
# - La classe sur l'espérance de survie (une meilleure classe est égale à plus de chance de survie)
# - Le prix du billet sur l'espérance de survie (plus le billet est cher plus vous avez de chance de survivre)
# - Le sexe et l'âge (les enfants et les femmes ont davantage de chance de survivre)
# - Le nombre de personnes avec qui vous voyagez (être seul n'est pas favorable mais être trop nombreux non plus).

# %% [markdown]
# ## Etape 3 : Data Preparation

# %% [markdown]
# ### Feature engineering

# %% [markdown]
# Maintenant que nous avons réalisé nos analyses nous allons devoir traiter certaines variables afin qu'elles soient interprétables pour notre modèle. C'est notamment le cas pour :
# - Le port d'embarquement qu'il faut convertir en valeur numérique
# - Le titre qu'il faut également convertir en valeur numérique

# %% [markdown]
# #### Conversion de la variable du port d'embarquement en attribuant des valeurs numériques

# %%
ports = {"S": 0, "C": 1, "Q": 2}
data = [train, test]

for dataset in data:
    dataset['Embarked'] = dataset['Embarked'].map(ports)

# %%
# Vérification que la modification est bien appliquée pour le dataset de train
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#       Fare  Embarked Title  relatives voyageur_seul
# 0   7.2500         0    Mr          1           Non
# 1  71.2833         1   Mrs          1           Non
# 2   7.9250         0  Miss          0           Oui
# 3  53.1000         0   Mrs          1           Non
# 4   8.0500         0    Mr          0           Oui

# %%
# Vérification que la modification est bien appliquée pour le dataset de test
test.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 881          892       NaN       3
# 882          893       NaN       3
# 883          894       NaN       2
# 884          895       NaN       3
# 885          896       NaN       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 881                              Kelly, Mr. James    0  34.5      0      0
# 882              Wilkes, Mrs. James (Ellen Needs)    1  47.0      1      0
# 883                     Myles, Mr. Thomas Francis    0  62.0      0      0
# 884                              Wirz, Mr. Albert    0  27.0      0      0
# 885  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.0      1      1
#
#         Fare  Embarked Title  relatives voyageur_seul
# 881   7.8292         2    Mr          0           Oui
# 882   7.0000         0   Mrs          1           Non
# 883   9.6875         2    Mr          0           Oui
# 884   8.6625         0    Mr          0           Oui
# 885  12.2875         0   Mrs          2           Non

# %% [markdown]
# #### Conversion de la variable du titre en attribuant des valeurs numériques

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rev": 5, "Dr": 6}
data = [train, test]

for dataset in data:
    dataset['Title'] = dataset['Title'].map(title_mapping)

# %%
# Vérification que la modification est bien appliquée pour le dataset de train
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#       Fare  Embarked  Title  relatives voyageur_seul
# 0   7.2500         0      1          1           Non
# 1  71.2833         1      3          1           Non
# 2   7.9250         0      2          0           Oui
# 3  53.1000         0      3          1           Non
# 4   8.0500         0      1          0           Oui

# %%
# Vérification que la modification est bien appliquée pour le dataset de test
test.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 881          892       NaN       3
# 882          893       NaN       3
# 883          894       NaN       2
# 884          895       NaN       3
# 885          896       NaN       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 881                              Kelly, Mr. James    0  34.5      0      0
# 882              Wilkes, Mrs. James (Ellen Needs)    1  47.0      1      0
# 883                     Myles, Mr. Thomas Francis    0  62.0      0      0
# 884                              Wirz, Mr. Albert    0  27.0      0      0
# 885  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.0      1      1
#
#         Fare  Embarked  Title  relatives voyageur_seul
# 881   7.8292         2      1          0           Oui
# 882   7.0000         0      3          1           Non
# 883   9.6875         2      1          0           Oui
# 884   8.6625         0      1          0           Oui
# 885  12.2875         0      3          2           Non

# %% [markdown]
# ### Préparation du modèle de Machine learning

# %% [markdown]
# Ces lignes permettent de préparer les données pour un modèle de machine learning en supprimant certaines colonnes, en extrayant la variable cible "Survived" et en remplaçant les valeurs manquantes dans le jeu de données de test.

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in c:\users\kcho\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\kcho\anaconda3\lib\site-packages (from catboost) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\kcho\anaconda3\lib\site-packages (from catboost) (3.5.2)
# Requirement already satisfied: scipy in c:\users\kcho\anaconda3\lib\site-packages (from catboost) (1.9.1)
# Requirement already satisfied: six in c:\users\kcho\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\kcho\anaconda3\lib\site-packages (from catboost) (1.4.4)
# Requirement already satisfied: plotly in c:\users\kcho\anaconda3\lib\site-packages (from catboost) (5.9.0)
# Requirement already satisfied: graphviz in c:\users\kcho\anaconda3\lib\site-packages (from catboost) (0.20.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\kcho\anaconda3\lib\site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kcho\anaconda3\lib\site-packages (from pandas>=0.24.0->catboost) (2022.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kcho\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kcho\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\kcho\anaconda3\lib\site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kcho\anaconda3\lib\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kcho\anaconda3\lib\site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kcho\anaconda3\lib\site-packages (from matplotlib->catboost) (9.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kcho\anaconda3\lib\site-packages (from plotly->catboost) (8.0.1)

# %%
X_train = train.drop(["Survived","Name","voyageur_seul"], axis=1)
Y_train = train["Survived"]
X_test  = test.drop(["PassengerId","Name","voyageur_seul"], axis=1).copy()
X_test["Survived"] = X_test["Survived"].fillna(-1)
X_train.shape, Y_train.shape, X_test.shape
# Out:
# ((881, 10), (881,), (418, 10))

# %% [markdown]
# Une fois les données préparées il suffit de mettre en place le modèle désiré et de sélectionner le plus pertinent. J'ai décidé de fonctionner en deux étapes:
# 1) La première méthode ne divise pas les données en jeux de validation et d'entraînement. En effet, dans la première méthode le modèle se base sur l'accuracy (la précision) il est construit en utilisant l'ensemble des données d'entraînement (X_train et Y_train) sans diviser les données en ensembles de validation et d'entraînement distincts.
#
# 2) La deuxième méthode utilise la validation croisée avec StratifiedShuffleSplit, qui divise les données en plusieurs jeux de validation et d'entraînement pour évaluer la performance du modèle de manière plus fiable. Dans cette méthode je vais réaliser une validation croisée sur trois splits différents de mes données d'entraînement
#
# Cela permettra d'avoir 2 points de vue différents sur nos modèles et de croiser les méthodologies.

# %% [markdown]
# ## Etape 4 : Modeling

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression, Perceptron, SGDClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
#Pour ignorer les warnings
import warnings
warnings.filterwarnings('ignore')
print('-'*25)
# Logistic Regression
logreg = LogisticRegression()
logreg.fit(X_train, Y_train)
Y_pred = logreg.predict(X_test)
acc_log = round(logreg.score(X_train, Y_train) * 100, 2)
acc_log
# Out:
# -------------------------
# 81.27

# %%
# Gradient Boosting Classifier
from sklearn.ensemble import GradientBoostingClassifier
gbk = GradientBoostingClassifier()
gbk.fit(X_train, Y_train)
Y_pred = gbk.predict(X_test)
acc_gbk = round(gbk.score(X_train, Y_train) * 100, 2)
acc_gbk
# Out:
# 90.47

# %%
# Support Vector Machines
#Pour ignorer les warnings
import warnings
warnings.filterwarnings('ignore')
print('-'*25)
svc = SVC()
svc.fit(X_train, Y_train)
Y_pred = svc.predict(X_test)
acc_svc = round(svc.score(X_train, Y_train) * 100, 2)
acc_svc
# Out:
# -------------------------
# 66.17

# %%
# KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, Y_train)
Y_pred = knn.predict(X_test)
acc_knn = round(knn.score(X_train, Y_train) * 100, 2)
acc_knn
# Out:
# 80.25

# %%
# Gaussian Naive Bayes
gaussian = GaussianNB()
gaussian.fit(X_train, Y_train)
Y_pred = gaussian.predict(X_test)
acc_gaussian = round(gaussian.score(X_train, Y_train) * 100, 2)
acc_gaussian
# Out:
# 80.7

# %%
#Perceptron
perceptron = Perceptron()
knn = KNeighborsClassifier(n_neighbors = 3)
perceptron.fit(X_train, Y_train)
Y_pred = perceptron.predict(X_test)
acc_perceptron = round(perceptron.score(X_train, Y_train) * 100, 2)
acc_perceptron
# Out:
# 66.63

# %%
# Stochastic Gradient Descent
sgd = SGDClassifier()
sgd.fit(X_train, Y_train)
Y_pred = sgd.predict(X_test)
acc_sgd = round(sgd.score(X_train, Y_train) * 100, 2)
acc_sgd
# Out:
# 73.78

# %% [markdown]
# Avec cette première méthodologie on obtient un modèle à 90,47% avec le 'Gradient Boosting Classifier'. Ce serait donc le modèle le plus performant sans split les données d'entrainement. Cependant, dans cette méthodologie nous avons un risque d'overfitting. Voyons les résultats de notre deuxième méthode.

# %%
from sklearn.model_selection import train_test_split

# Supprimer les colonnes inutiles et la colonne "Survived" du jeu de test
X_train = train.drop(["Survived","Name","voyageur_seul"], axis=1)
Y_train = train["Survived"]
X_test  = test.drop(["PassengerId","Name","voyageur_seul"], axis=1).copy()

# Remplacer les valeurs manquantes de la colonne "Survived" par -1
X_test["Survived"] = X_test["Survived"].fillna(-1)

# Diviser les données d'entraînement en jeux d'entraînement et de validation
x_train, x_val, y_train, y_val = train_test_split(X_train, Y_train, test_size = 0.22, random_state = 0)

# Afficher les dimensions des jeux de données
print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(X_test.shape)
# Out:
# (687, 10) (687,)
# (194, 10) (194,)
# (418, 10)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression

# Supprimer les colonnes inutiles et la colonne "Survived" du jeu de test
X_train = train.drop(["Survived","Name","voyageur_seul"], axis=1)
Y_train = train["Survived"]
X_test  = test.drop(["PassengerId","Name","voyageur_seul"], axis=1).copy()

# Remplacer les valeurs manquantes de la colonne "Survived" par -1
X_test["Survived"] = X_test["Survived"].fillna(-1)

# Diviser les données d'entraînement en jeux d'entraînement et de validation
x_train, x_val, y_train, y_val = train_test_split(X_train, Y_train, test_size = 0.22, random_state = 0)

# Afficher les dimensions des jeux de données
print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(X_test.shape)

# Définir les classifieurs à tester
classifiers = [
    KNeighborsClassifier(3),
    DecisionTreeClassifier(),
    CatBoostClassifier(),
    XGBClassifier(),
    RandomForestClassifier(),
    AdaBoostClassifier(),
    GradientBoostingClassifier(),
    GaussianNB(),
    LinearDiscriminantAnalysis(),
    QuadraticDiscriminantAnalysis(),
    LogisticRegression()
]

# Définir le split pour la validation croisée
SSplit = StratifiedShuffleSplit(n_splits=3, test_size=0.2, random_state=42)

# Boucle sur les splits et les classifieurs pour obtenir la précision moyenne sur la validation
for train_index, test_index in SSplit.split(X_train, Y_train):
    x_train, x_test = X_train.iloc[train_index], X_train.iloc[test_index]
    y_train, y_test = Y_train.iloc[train_index], Y_train.iloc[test_index]
    for clf in classifiers:
        clf.fit(x_train, y_train)
        y_pred = clf.predict(x_test)
        acc = accuracy_score(y_test, y_pred)
        print(clf.__class__.__name__, acc)
# Out:
# (687, 10) (687,)
# (194, 10) (194,)
# (418, 10)
# KNeighborsClassifier 0.6271186440677966
# DecisionTreeClassifier 0.7627118644067796
# Learning rate set to 0.008868
# 0:	learn: 0.6876345	total: 152ms	remaining: 2m 31s
# 1:	learn: 0.6807430	total: 155ms	remaining: 1m 17s
# 2:	learn: 0.6742153	total: 158ms	remaining: 52.6s
# 3:	learn: 0.6692265	total: 162ms	remaining: 40.4s
# 4:	learn: 0.6632676	total: 165ms	remaining: 32.9s
# 5:	learn: 0.6578032	total: 169ms	remaining: 28s
# 6:	learn: 0.6522321	total: 173ms	remaining: 24.5s
# 7:	learn: 0.6472208	total: 176ms	remaining: 21.9s
# 8:	learn: 0.6409945	total: 182ms	remaining: 20s
# 9:	learn: 0.6358152	total: 186ms	remaining: 18.5s
# 10:	learn: 0.6308981	total: 190ms	remaining: 17.1s
# 11:	learn: 0.6255336	total: 195ms	remaining: 16.1s
# 12:	learn: 0.6201626	total: 200ms	remaining: 15.2s
# 13:	learn: 0.6160845	total: 202ms	remaining: 14.2s
# 14:	learn: 0.6126223	total: 207ms	remaining: 13.6s
# 15:	learn: 0.6072698	total: 211ms	remaining: 12.9s
# 16:	learn: 0.6043400	total: 213ms	remaining: 12.3s
# 17:	learn: 0.5998674	total: 216ms	remaining: 11.8s
# 18:	learn: 0.5947621	total: 219ms	remaining: 11.3s
# 19:	learn: 0.5903407	total: 222ms	remaining: 10.9s
# 20:	learn: 0.5857013	total: 224ms	remaining: 10.4s
# 21:	learn: 0.5812081	total: 227ms	remaining: 10.1s
# 22:	learn: 0.5770776	total: 230ms	remaining: 9.77s
# 23:	learn: 0.5725599	total: 233ms	remaining: 9.46s
# 24:	learn: 0.5679553	total: 235ms	remaining: 9.17s
# 25:	learn: 0.5643452	total: 237ms	remaining: 8.9s
# 26:	learn: 0.5606193	total: 240ms	remaining: 8.64s
# 27:	learn: 0.5565539	total: 242ms	remaining: 8.39s
# 28:	learn: 0.5536149	total: 244ms	remaining: 8.16s
# 29:	learn: 0.5502625	total: 246ms	remaining: 7.94s
# 30:	learn: 0.5475714	total: 247ms	remaining: 7.72s
# 31:	learn: 0.5442990	total: 249ms	remaining: 7.53s
# 32:	learn: 0.5406243	total: 251ms	remaining: 7.36s
# 33:	learn: 0.5366663	total: 253ms	remaining: 7.19s
# 34:	learn: 0.5338638	total: 255ms	remaining: 7.03s
# 35:	learn: 0.5303346	total: 257ms	remaining: 6.87s
# 36:	learn: 0.5274484	total: 258ms	remaining: 6.73s
# 37:	learn: 0.5242543	total: 260ms	remaining: 6.59s
# 38:	learn: 0.5213025	total: 262ms	remaining: 6.46s
# 39:	learn: 0.5178292	total: 264ms	remaining: 6.33s
# 40:	learn: 0.5146263	total: 265ms	remaining: 6.21s
# 41:	learn: 0.5115093	total: 267ms	remaining: 6.09s
# 42:	learn: 0.5093625	total: 268ms	remaining: 5.97s
# 43:	learn: 0.5066109	total: 269ms	remaining: 5.85s
# 44:	learn: 0.5045657	total: 271ms	remaining: 5.74s
# 45:	learn: 0.5012580	total: 272ms	remaining: 5.64s
# 46:	learn: 0.4994221	total: 273ms	remaining: 5.54s
# 47:	learn: 0.4969550	total: 275ms	remaining: 5.44s
# 48:	learn: 0.4946426	total: 275ms	remaining: 5.35s
# 49:	learn: 0.4916587	total: 277ms	remaining: 5.26s
# 50:	learn: 0.4893670	total: 278ms	remaining: 5.17s
# 51:	learn: 0.4866575	total: 279ms	remaining: 5.08s
# 52:	learn: 0.4841664	total: 280ms	remaining: 5s
# 53:	learn: 0.4817765	total: 281ms	remaining: 4.92s
# 54:	learn: 0.4799871	total: 282ms	remaining: 4.84s
# 55:	learn: 0.4778663	total: 283ms	remaining: 4.77s
# 56:	learn: 0.4756447	total: 284ms	remaining: 4.7s
# 57:	learn: 0.4737095	total: 285ms	remaining: 4.63s
# 58:	learn: 0.4715085	total: 286ms	remaining: 4.56s
# 59:	learn: 0.4691802	total: 287ms	remaining: 4.5s
# 60:	learn: 0.4671501	total: 288ms	remaining: 4.44s
# 61:	learn: 0.4650707	total: 289ms	remaining: 4.38s
# 62:	learn: 0.4632244	total: 291ms	remaining: 4.32s
# 63:	learn: 0.4615025	total: 292ms	remaining: 4.27s
# 64:	learn: 0.4596317	total: 293ms	remaining: 4.21s
# 65:	learn: 0.4572857	total: 294ms	remaining: 4.16s
# 66:	learn: 0.4554530	total: 295ms	remaining: 4.11s
# 67:	learn: 0.4536620	total: 296ms	remaining: 4.06s
# 68:	learn: 0.4517288	total: 297ms	remaining: 4.01s
# 69:	learn: 0.4508738	total: 298ms	remaining: 3.96s
# 70:	learn: 0.4496018	total: 299ms	remaining: 3.91s
# 71:	learn: 0.4483113	total: 300ms	remaining: 3.86s
# 72:	learn: 0.4464253	total: 301ms	remaining: 3.82s
# 73:	learn: 0.4445877	total: 302ms	remaining: 3.78s
# 74:	learn: 0.4428659	total: 303ms	remaining: 3.74s
# 75:	learn: 0.4412685	total: 304ms	remaining: 3.69s
# 76:	learn: 0.4395486	total: 305ms	remaining: 3.66s
# 77:	learn: 0.4377778	total: 306ms	remaining: 3.62s
# 78:	learn: 0.4359573	total: 307ms	remaining: 3.58s
# 79:	learn: 0.4346263	total: 308ms	remaining: 3.55s
# 80:	learn: 0.4331642	total: 309ms	remaining: 3.51s
# 81:	learn: 0.4318115	total: 311ms	remaining: 3.48s
# 82:	learn: 0.4304380	total: 312ms	remaining: 3.44s
# 83:	learn: 0.4290257	total: 313ms	remaining: 3.41s
# 84:	learn: 0.4272044	total: 314ms	remaining: 3.38s
# 85:	learn: 0.4257980	total: 315ms	remaining: 3.35s
# 86:	learn: 0.4244439	total: 316ms	remaining: 3.31s
# 87:	learn: 0.4230733	total: 317ms	remaining: 3.28s
# 88:	learn: 0.4217092	total: 318ms	remaining: 3.25s
# 89:	learn: 0.4206474	total: 319ms	remaining: 3.23s
# 90:	learn: 0.4195955	total: 320ms	remaining: 3.2s
# 91:	learn: 0.4189570	total: 321ms	remaining: 3.17s
# 92:	learn: 0.4175745	total: 322ms	remaining: 3.14s
# 93:	learn: 0.4162211	total: 323ms	remaining: 3.11s
# 94:	learn: 0.4150249	total: 324ms	remaining: 3.09s
# 95:	learn: 0.4144265	total: 325ms	remaining: 3.06s
# 96:	learn: 0.4138552	total: 326ms	remaining: 3.03s
# 97:	learn: 0.4124314	total: 327ms	remaining: 3.01s
# 98:	learn: 0.4112505	total: 328ms	remaining: 2.99s
# 99:	learn: 0.4098213	total: 329ms	remaining: 2.96s
# 100:	learn: 0.4086181	total: 330ms	remaining: 2.94s
# 101:	learn: 0.4076537	total: 331ms	remaining: 2.92s
# 102:	learn: 0.4065596	total: 332ms	remaining: 2.89s
# 103:	learn: 0.4057499	total: 333ms	remaining: 2.87s
# 104:	learn: 0.4045914	total: 334ms	remaining: 2.85s
# 105:	learn: 0.4035569	total: 335ms	remaining: 2.83s
# 106:	learn: 0.4027702	total: 336ms	remaining: 2.81s
# 107:	learn: 0.4016276	total: 337ms	remaining: 2.79s
# 108:	learn: 0.4006069	total: 339ms	remaining: 2.77s
# 109:	learn: 0.3995212	total: 340ms	remaining: 2.75s
# 110:	learn: 0.3991677	total: 340ms	remaining: 2.73s
# 111:	learn: 0.3988728	total: 341ms	remaining: 2.7s
# 112:	learn: 0.3978033	total: 342ms	remaining: 2.68s
# 113:	learn: 0.3969629	total: 343ms	remaining: 2.67s
# 114:	learn: 0.3962718	total: 344ms	remaining: 2.65s
# 115:	learn: 0.3954235	total: 345ms	remaining: 2.63s
# 116:	learn: 0.3944935	total: 346ms	remaining: 2.61s
# 117:	learn: 0.3935942	total: 347ms	remaining: 2.6s
# 118:	learn: 0.3924847	total: 349ms	remaining: 2.58s
# 119:	learn: 0.3913119	total: 350ms	remaining: 2.56s
# 120:	learn: 0.3907915	total: 351ms	remaining: 2.55s
# 121:	learn: 0.3899448	total: 352ms	remaining: 2.53s
# 122:	learn: 0.3888502	total: 353ms	remaining: 2.52s
# 123:	learn: 0.3879629	total: 354ms	remaining: 2.5s
# 124:	learn: 0.3874862	total: 355ms	remaining: 2.48s
# 125:	learn: 0.3866184	total: 356ms	remaining: 2.47s
# 126:	learn: 0.3856205	total: 357ms	remaining: 2.45s
# 127:	learn: 0.3849803	total: 358ms	remaining: 2.44s
# 128:	learn: 0.3841749	total: 359ms	remaining: 2.42s
# 129:	learn: 0.3836430	total: 360ms	remaining: 2.41s
# 130:	learn: 0.3828995	total: 361ms	remaining: 2.4s
# 131:	learn: 0.3823970	total: 362ms	remaining: 2.38s
# 132:	learn: 0.3818064	total: 363ms	remaining: 2.37s
# 133:	learn: 0.3808935	total: 364ms	remaining: 2.35s
# 134:	learn: 0.3803004	total: 365ms	remaining: 2.34s
# 135:	learn: 0.3797978	total: 366ms	remaining: 2.33s
# 136:	learn: 0.3791098	total: 367ms	remaining: 2.31s
# 137:	learn: 0.3786171	total: 369ms	remaining: 2.3s
# 138:	learn: 0.3777810	total: 370ms	remaining: 2.29s
# 139:	learn: 0.3771210	total: 371ms	remaining: 2.28s
# 140:	learn: 0.3765150	total: 372ms	remaining: 2.27s
# 141:	learn: 0.3760764	total: 373ms	remaining: 2.25s
# 142:	learn: 0.3751620	total: 374ms	remaining: 2.24s
# 143:	learn: 0.3744371	total: 376ms	remaining: 2.23s
# 144:	learn: 0.3742100	total: 377ms	remaining: 2.22s
# 145:	learn: 0.3737232	total: 378ms	remaining: 2.21s
# 146:	learn: 0.3735272	total: 379ms	remaining: 2.2s
# 147:	learn: 0.3730844	total: 379ms	remaining: 2.18s
# 148:	learn: 0.3728755	total: 380ms	remaining: 2.17s
# 149:	learn: 0.3727426	total: 380ms	remaining: 2.15s
# 150:	learn: 0.3722777	total: 381ms	remaining: 2.14s
# 151:	learn: 0.3716137	total: 383ms	remaining: 2.13s
# 152:	learn: 0.3711061	total: 384ms	remaining: 2.12s
# 153:	learn: 0.3703470	total: 385ms	remaining: 2.11s
# 154:	learn: 0.3697570	total: 386ms	remaining: 2.1s
# 155:	learn: 0.3692293	total: 387ms	remaining: 2.09s
# 156:	learn: 0.3685617	total: 388ms	remaining: 2.08s
# 157:	learn: 0.3681336	total: 389ms	remaining: 2.07s
# 158:	learn: 0.3676328	total: 390ms	remaining: 2.06s
# 159:	learn: 0.3672211	total: 391ms	remaining: 2.05s
# 160:	learn: 0.3666599	total: 392ms	remaining: 2.04s
# 161:	learn: 0.3659616	total: 393ms	remaining: 2.03s
# 162:	learn: 0.3655880	total: 394ms	remaining: 2.02s
# 163:	learn: 0.3650488	total: 396ms	remaining: 2.02s
# 164:	learn: 0.3644368	total: 397ms	remaining: 2.01s
# 165:	learn: 0.3639191	total: 398ms	remaining: 2s
# 166:	learn: 0.3631752	total: 400ms	remaining: 1.99s
# 167:	learn: 0.3624144	total: 401ms	remaining: 1.99s
# 168:	learn: 0.3619156	total: 402ms	remaining: 1.98s
# 169:	learn: 0.3615359	total: 404ms	remaining: 1.97s
# 170:	learn: 0.3611140	total: 405ms	remaining: 1.96s
# 171:	learn: 0.3606117	total: 406ms	remaining: 1.95s
# 172:	learn: 0.3601121	total: 407ms	remaining: 1.95s
# 173:	learn: 0.3597707	total: 408ms	remaining: 1.94s
# 174:	learn: 0.3591929	total: 410ms	remaining: 1.93s
# 175:	learn: 0.3587417	total: 411ms	remaining: 1.92s
# 176:	learn: 0.3581675	total: 412ms	remaining: 1.91s
# 177:	learn: 0.3577543	total: 413ms	remaining: 1.91s
# 178:	learn: 0.3573791	total: 414ms	remaining: 1.9s
# 179:	learn: 0.3569552	total: 415ms	remaining: 1.89s
# 180:	learn: 0.3563848	total: 416ms	remaining: 1.88s
# 181:	learn: 0.3560692	total: 417ms	remaining: 1.87s
# 182:	learn: 0.3555918	total: 418ms	remaining: 1.86s
# 183:	learn: 0.3549578	total: 419ms	remaining: 1.86s
# 184:	learn: 0.3543673	total: 420ms	remaining: 1.85s
# 185:	learn: 0.3537208	total: 421ms	remaining: 1.84s
# 186:	learn: 0.3533928	total: 422ms	remaining: 1.83s
# 187:	learn: 0.3531995	total: 423ms	remaining: 1.82s
# 188:	learn: 0.3528117	total: 424ms	remaining: 1.82s
# 189:	learn: 0.3523020	total: 425ms	remaining: 1.81s
# 190:	learn: 0.3518490	total: 426ms	remaining: 1.8s
# 191:	learn: 0.3513932	total: 427ms	remaining: 1.8s
# 192:	learn: 0.3512093	total: 428ms	remaining: 1.79s
# 193:	learn: 0.3508016	total: 429ms	remaining: 1.78s
# 194:	learn: 0.3504249	total: 430ms	remaining: 1.77s
# 195:	learn: 0.3500837	total: 431ms	remaining: 1.77s
# 196:	learn: 0.3497886	total: 432ms	remaining: 1.76s
# 197:	learn: 0.3491737	total: 434ms	remaining: 1.75s
# 198:	learn: 0.3487621	total: 435ms	remaining: 1.75s
# 199:	learn: 0.3482980	total: 436ms	remaining: 1.74s
# 200:	learn: 0.3478327	total: 437ms	remaining: 1.74s
# 201:	learn: 0.3475068	total: 438ms	remaining: 1.73s
# 202:	learn: 0.3472267	total: 439ms	remaining: 1.72s
# 203:	learn: 0.3470229	total: 440ms	remaining: 1.72s
# 204:	learn: 0.3466196	total: 441ms	remaining: 1.71s
# 205:	learn: 0.3462051	total: 442ms	remaining: 1.7s
# 206:	learn: 0.3456513	total: 443ms	remaining: 1.7s
# 207:	learn: 0.3453850	total: 444ms	remaining: 1.69s
# 208:	learn: 0.3449378	total: 445ms	remaining: 1.68s
# 209:	learn: 0.3445625	total: 446ms	remaining: 1.68s
# 210:	learn: 0.3440663	total: 447ms	remaining: 1.67s
# 211:	learn: 0.3436035	total: 448ms	remaining: 1.67s
# 212:	learn: 0.3432416	total: 449ms	remaining: 1.66s
# 213:	learn: 0.3429064	total: 451ms	remaining: 1.65s
# 214:	learn: 0.3425190	total: 452ms	remaining: 1.65s
# 215:	learn: 0.3421932	total: 453ms	remaining: 1.64s
# 216:	learn: 0.3417754	total: 454ms	remaining: 1.64s
# 217:	learn: 0.3413550	total: 455ms	remaining: 1.63s
# 218:	learn: 0.3410293	total: 456ms	remaining: 1.63s
# 219:	learn: 0.3407385	total: 457ms	remaining: 1.62s
# 220:	learn: 0.3402984	total: 458ms	remaining: 1.61s
# 221:	learn: 0.3398180	total: 459ms	remaining: 1.61s
# 222:	learn: 0.3396001	total: 460ms	remaining: 1.6s
# 223:	learn: 0.3394925	total: 461ms	remaining: 1.59s
# 224:	learn: 0.3390697	total: 462ms	remaining: 1.59s
# 225:	learn: 0.3387002	total: 463ms	remaining: 1.58s
# 226:	learn: 0.3383099	total: 464ms	remaining: 1.58s
# 227:	learn: 0.3379072	total: 465ms	remaining: 1.57s
# 228:	learn: 0.3376272	total: 466ms	remaining: 1.57s
# 229:	learn: 0.3372956	total: 467ms	remaining: 1.56s
# 230:	learn: 0.3370567	total: 468ms	remaining: 1.56s
# 231:	learn: 0.3365284	total: 469ms	remaining: 1.55s
# 232:	learn: 0.3361011	total: 470ms	remaining: 1.55s
# 233:	learn: 0.3358794	total: 472ms	remaining: 1.54s
# 234:	learn: 0.3355836	total: 473ms	remaining: 1.54s
# 235:	learn: 0.3350956	total: 474ms	remaining: 1.53s
# 236:	learn: 0.3347569	total: 475ms	remaining: 1.53s
# 237:	learn: 0.3346212	total: 476ms	remaining: 1.52s
# 238:	learn: 0.3343919	total: 477ms	remaining: 1.52s
# 239:	learn: 0.3340189	total: 478ms	remaining: 1.51s
# 240:	learn: 0.3338057	total: 479ms	remaining: 1.51s
# 241:	learn: 0.3335504	total: 480ms	remaining: 1.5s
# 242:	learn: 0.3333538	total: 481ms	remaining: 1.5s
# 243:	learn: 0.3332282	total: 482ms	remaining: 1.49s
# 244:	learn: 0.3328619	total: 483ms	remaining: 1.49s
# 245:	learn: 0.3327734	total: 484ms	remaining: 1.48s
# 246:	learn: 0.3325563	total: 485ms	remaining: 1.48s
# 247:	learn: 0.3324260	total: 486ms	remaining: 1.47s
# 248:	learn: 0.3322084	total: 487ms	remaining: 1.47s
# 249:	learn: 0.3319955	total: 488ms	remaining: 1.46s
# 250:	learn: 0.3317345	total: 489ms	remaining: 1.46s
# 251:	learn: 0.3312747	total: 490ms	remaining: 1.46s
# 252:	learn: 0.3310044	total: 491ms	remaining: 1.45s
# 253:	learn: 0.3307465	total: 492ms	remaining: 1.45s
# 254:	learn: 0.3305515	total: 494ms	remaining: 1.44s
# 255:	learn: 0.3303315	total: 495ms	remaining: 1.44s
# 256:	learn: 0.3299366	total: 496ms	remaining: 1.43s
# 257:	learn: 0.3295273	total: 497ms	remaining: 1.43s
# 258:	learn: 0.3293176	total: 498ms	remaining: 1.42s
# 259:	learn: 0.3290579	total: 499ms	remaining: 1.42s
# 260:	learn: 0.3287197	total: 500ms	remaining: 1.42s
# 261:	learn: 0.3285452	total: 501ms	remaining: 1.41s
# 262:	learn: 0.3281282	total: 502ms	remaining: 1.41s
# 263:	learn: 0.3278113	total: 503ms	remaining: 1.4s
# 264:	learn: 0.3276742	total: 504ms	remaining: 1.4s
# 265:	learn: 0.3274620	total: 505ms	remaining: 1.39s
# 266:	learn: 0.3271727	total: 506ms	remaining: 1.39s
# 267:	learn: 0.3269910	total: 507ms	remaining: 1.38s
# 268:	learn: 0.3266813	total: 508ms	remaining: 1.38s
# 269:	learn: 0.3263746	total: 509ms	remaining: 1.38s
# 270:	learn: 0.3260875	total: 510ms	remaining: 1.37s
# 271:	learn: 0.3258574	total: 511ms	remaining: 1.37s
# 272:	learn: 0.3255621	total: 512ms	remaining: 1.36s
# 273:	learn: 0.3253723	total: 514ms	remaining: 1.36s
# 274:	learn: 0.3252049	total: 515ms	remaining: 1.36s
# 275:	learn: 0.3248147	total: 516ms	remaining: 1.35s
# 276:	learn: 0.3244314	total: 517ms	remaining: 1.35s
# 277:	learn: 0.3239023	total: 518ms	remaining: 1.34s
# 278:	learn: 0.3235372	total: 519ms	remaining: 1.34s
# 279:	learn: 0.3233247	total: 520ms	remaining: 1.34s
# 280:	learn: 0.3230410	total: 521ms	remaining: 1.33s
# 281:	learn: 0.3225505	total: 522ms	remaining: 1.33s
# 282:	learn: 0.3223712	total: 523ms	remaining: 1.32s
# 283:	learn: 0.3220545	total: 524ms	remaining: 1.32s
# 284:	learn: 0.3218314	total: 525ms	remaining: 1.32s
# 285:	learn: 0.3216914	total: 526ms	remaining: 1.31s
# 286:	learn: 0.3213958	total: 527ms	remaining: 1.31s
# 287:	learn: 0.3213262	total: 528ms	remaining: 1.3s
# 288:	learn: 0.3210669	total: 529ms	remaining: 1.3s
# 289:	learn: 0.3209159	total: 531ms	remaining: 1.3s
# 290:	learn: 0.3207474	total: 532ms	remaining: 1.29s
# 291:	learn: 0.3205049	total: 533ms	remaining: 1.29s
# 292:	learn: 0.3203520	total: 534ms	remaining: 1.29s
# 293:	learn: 0.3198916	total: 536ms	remaining: 1.29s
# 294:	learn: 0.3196215	total: 537ms	remaining: 1.28s
# 295:	learn: 0.3193914	total: 538ms	remaining: 1.28s
# 296:	learn: 0.3190634	total: 539ms	remaining: 1.28s
# 297:	learn: 0.3189799	total: 540ms	remaining: 1.27s
# 298:	learn: 0.3187733	total: 541ms	remaining: 1.27s
# 299:	learn: 0.3185828	total: 542ms	remaining: 1.26s
# 300:	learn: 0.3182178	total: 543ms	remaining: 1.26s
# 301:	learn: 0.3178510	total: 545ms	remaining: 1.26s
# 302:	learn: 0.3176262	total: 546ms	remaining: 1.26s
# 303:	learn: 0.3172477	total: 547ms	remaining: 1.25s
# 304:	learn: 0.3169203	total: 549ms	remaining: 1.25s
# 305:	learn: 0.3166962	total: 550ms	remaining: 1.25s
# 306:	learn: 0.3163750	total: 551ms	remaining: 1.24s
# 307:	learn: 0.3161532	total: 552ms	remaining: 1.24s
# 308:	learn: 0.3158431	total: 554ms	remaining: 1.24s
# 309:	learn: 0.3155832	total: 555ms	remaining: 1.23s
# 310:	learn: 0.3151581	total: 556ms	remaining: 1.23s
# 311:	learn: 0.3150483	total: 557ms	remaining: 1.23s
# 312:	learn: 0.3148079	total: 559ms	remaining: 1.23s
# 313:	learn: 0.3147742	total: 560ms	remaining: 1.22s
# 314:	learn: 0.3145382	total: 561ms	remaining: 1.22s
# 315:	learn: 0.3142561	total: 562ms	remaining: 1.22s
# 316:	learn: 0.3140898	total: 563ms	remaining: 1.21s
# 317:	learn: 0.3138026	total: 564ms	remaining: 1.21s
# 318:	learn: 0.3136243	total: 566ms	remaining: 1.21s
# 319:	learn: 0.3134282	total: 567ms	remaining: 1.2s
# 320:	learn: 0.3132380	total: 568ms	remaining: 1.2s
# 321:	learn: 0.3129178	total: 569ms	remaining: 1.2s
# 322:	learn: 0.3126597	total: 570ms	remaining: 1.2s
# 323:	learn: 0.3124670	total: 571ms	remaining: 1.19s
# 324:	learn: 0.3122192	total: 573ms	remaining: 1.19s
# 325:	learn: 0.3118689	total: 574ms	remaining: 1.19s
# 326:	learn: 0.3114576	total: 575ms	remaining: 1.18s
# 327:	learn: 0.3113954	total: 576ms	remaining: 1.18s
# 328:	learn: 0.3111561	total: 577ms	remaining: 1.18s
# 329:	learn: 0.3110031	total: 578ms	remaining: 1.17s
# 330:	learn: 0.3108094	total: 579ms	remaining: 1.17s
# 331:	learn: 0.3106324	total: 580ms	remaining: 1.17s
# 332:	learn: 0.3105819	total: 581ms	remaining: 1.16s
# 333:	learn: 0.3103032	total: 582ms	remaining: 1.16s
# 334:	learn: 0.3101801	total: 583ms	remaining: 1.16s
# 335:	learn: 0.3098927	total: 585ms	remaining: 1.16s
# 336:	learn: 0.3097370	total: 586ms	remaining: 1.15s
# 337:	learn: 0.3094752	total: 587ms	remaining: 1.15s
# 338:	learn: 0.3093019	total: 588ms	remaining: 1.15s
# 339:	learn: 0.3089682	total: 589ms	remaining: 1.14s
# 340:	learn: 0.3087573	total: 590ms	remaining: 1.14s
# 341:	learn: 0.3085553	total: 591ms	remaining: 1.14s
# 342:	learn: 0.3083492	total: 592ms	remaining: 1.13s
# 343:	learn: 0.3082295	total: 594ms	remaining: 1.13s
# 344:	learn: 0.3080869	total: 595ms	remaining: 1.13s
# 345:	learn: 0.3079561	total: 596ms	remaining: 1.13s
# 346:	learn: 0.3077581	total: 597ms	remaining: 1.12s
# 347:	learn: 0.3075954	total: 598ms	remaining: 1.12s
# 348:	learn: 0.3073633	total: 599ms	remaining: 1.12s
# 349:	learn: 0.3071244	total: 600ms	remaining: 1.11s
# 350:	learn: 0.3069759	total: 601ms	remaining: 1.11s
# 351:	learn: 0.3069193	total: 601ms	remaining: 1.11s
# 352:	learn: 0.3067710	total: 602ms	remaining: 1.1s
# 353:	learn: 0.3065316	total: 603ms	remaining: 1.1s
# 354:	learn: 0.3063945	total: 605ms	remaining: 1.1s
# 355:	learn: 0.3062643	total: 606ms	remaining: 1.09s
# 356:	learn: 0.3061088	total: 607ms	remaining: 1.09s
# 357:	learn: 0.3060126	total: 608ms	remaining: 1.09s
# 358:	learn: 0.3058731	total: 609ms	remaining: 1.09s
# 359:	learn: 0.3056737	total: 610ms	remaining: 1.08s
# 360:	learn: 0.3055820	total: 611ms	remaining: 1.08s
# 361:	learn: 0.3054359	total: 612ms	remaining: 1.08s
# 362:	learn: 0.3052647	total: 613ms	remaining: 1.07s
# 363:	learn: 0.3051427	total: 614ms	remaining: 1.07s
# 364:	learn: 0.3051375	total: 614ms	remaining: 1.07s
# 365:	learn: 0.3049650	total: 615ms	remaining: 1.06s
# 366:	learn: 0.3047413	total: 616ms	remaining: 1.06s
# 367:	learn: 0.3046491	total: 618ms	remaining: 1.06s
# 368:	learn: 0.3044941	total: 619ms	remaining: 1.06s
# 369:	learn: 0.3042168	total: 620ms	remaining: 1.05s
# 370:	learn: 0.3039899	total: 621ms	remaining: 1.05s
# 371:	learn: 0.3038928	total: 623ms	remaining: 1.05s
# 372:	learn: 0.3036832	total: 624ms	remaining: 1.05s
# 373:	learn: 0.3035958	total: 625ms	remaining: 1.04s
# 374:	learn: 0.3034011	total: 626ms	remaining: 1.04s
# 375:	learn: 0.3031654	total: 627ms	remaining: 1.04s
# 376:	learn: 0.3028097	total: 628ms	remaining: 1.04s
# 377:	learn: 0.3026997	total: 630ms	remaining: 1.04s
# 378:	learn: 0.3025556	total: 631ms	remaining: 1.03s
# 379:	learn: 0.3024166	total: 632ms	remaining: 1.03s
# 380:	learn: 0.3022141	total: 633ms	remaining: 1.03s
# 381:	learn: 0.3019745	total: 634ms	remaining: 1.02s
# 382:	learn: 0.3017566	total: 635ms	remaining: 1.02s
# 383:	learn: 0.3015132	total: 636ms	remaining: 1.02s
# 384:	learn: 0.3013992	total: 637ms	remaining: 1.02s
# 385:	learn: 0.3013017	total: 638ms	remaining: 1.01s
# 386:	learn: 0.3012003	total: 639ms	remaining: 1.01s
# 387:	learn: 0.3011121	total: 640ms	remaining: 1.01s
# 388:	learn: 0.3009300	total: 641ms	remaining: 1.01s
# 389:	learn: 0.3007469	total: 643ms	remaining: 1s
# 390:	learn: 0.3005088	total: 644ms	remaining: 1s
# 391:	learn: 0.3003508	total: 645ms	remaining: 1000ms
# 392:	learn: 0.3001869	total: 646ms	remaining: 997ms
# 393:	learn: 0.2998014	total: 647ms	remaining: 995ms
# 394:	learn: 0.2997297	total: 648ms	remaining: 993ms
# 395:	learn: 0.2996149	total: 649ms	remaining: 990ms
# 396:	learn: 0.2994864	total: 651ms	remaining: 988ms
# 397:	learn: 0.2993451	total: 652ms	remaining: 986ms
# 398:	learn: 0.2991250	total: 653ms	remaining: 984ms
# 399:	learn: 0.2990132	total: 654ms	remaining: 982ms
# 400:	learn: 0.2988676	total: 656ms	remaining: 979ms
# 401:	learn: 0.2987918	total: 657ms	remaining: 977ms
# 402:	learn: 0.2986386	total: 658ms	remaining: 974ms
# 403:	learn: 0.2984183	total: 659ms	remaining: 972ms
# 404:	learn: 0.2982102	total: 660ms	remaining: 969ms
# 405:	learn: 0.2981085	total: 661ms	remaining: 967ms
# 406:	learn: 0.2979686	total: 662ms	remaining: 965ms
# 407:	learn: 0.2978653	total: 663ms	remaining: 962ms
# 408:	learn: 0.2976954	total: 664ms	remaining: 960ms
# 409:	learn: 0.2976909	total: 665ms	remaining: 957ms
# 410:	learn: 0.2974187	total: 666ms	remaining: 954ms
# 411:	learn: 0.2972762	total: 667ms	remaining: 952ms
# 412:	learn: 0.2970651	total: 668ms	remaining: 949ms
# 413:	learn: 0.2968038	total: 669ms	remaining: 947ms
# 414:	learn: 0.2966515	total: 670ms	remaining: 945ms
# 415:	learn: 0.2964391	total: 671ms	remaining: 942ms
# 416:	learn: 0.2963617	total: 672ms	remaining: 940ms
# 417:	learn: 0.2963026	total: 673ms	remaining: 937ms
# 418:	learn: 0.2962495	total: 674ms	remaining: 935ms
# 419:	learn: 0.2959880	total: 675ms	remaining: 933ms
# 420:	learn: 0.2958772	total: 676ms	remaining: 930ms
# 421:	learn: 0.2957639	total: 677ms	remaining: 928ms
# 422:	learn: 0.2956134	total: 678ms	remaining: 925ms
# 423:	learn: 0.2954505	total: 679ms	remaining: 923ms
# 424:	learn: 0.2951666	total: 680ms	remaining: 921ms
# 425:	learn: 0.2949745	total: 682ms	remaining: 918ms
# 426:	learn: 0.2948320	total: 683ms	remaining: 916ms
# 427:	learn: 0.2947465	total: 684ms	remaining: 914ms
# 428:	learn: 0.2945349	total: 685ms	remaining: 911ms
# 429:	learn: 0.2943568	total: 686ms	remaining: 909ms
# 430:	learn: 0.2941839	total: 687ms	remaining: 907ms
# 431:	learn: 0.2940996	total: 688ms	remaining: 905ms
# 432:	learn: 0.2939522	total: 689ms	remaining: 902ms
# 433:	learn: 0.2938261	total: 690ms	remaining: 900ms
# 434:	learn: 0.2937250	total: 691ms	remaining: 898ms
# 435:	learn: 0.2935627	total: 692ms	remaining: 895ms
# 436:	learn: 0.2934491	total: 693ms	remaining: 893ms
# 437:	learn: 0.2932997	total: 694ms	remaining: 891ms
# 438:	learn: 0.2931554	total: 695ms	remaining: 889ms
# 439:	learn: 0.2930386	total: 696ms	remaining: 886ms
# 440:	learn: 0.2928955	total: 697ms	remaining: 884ms
# 441:	learn: 0.2927159	total: 698ms	remaining: 882ms
# 442:	learn: 0.2924824	total: 700ms	remaining: 880ms
# 443:	learn: 0.2923426	total: 701ms	remaining: 877ms
# 444:	learn: 0.2921932	total: 702ms	remaining: 875ms
# 445:	learn: 0.2919562	total: 703ms	remaining: 873ms
# 446:	learn: 0.2918463	total: 704ms	remaining: 871ms
# 447:	learn: 0.2916619	total: 705ms	remaining: 869ms
# 448:	learn: 0.2916089	total: 706ms	remaining: 866ms
# 449:	learn: 0.2914102	total: 707ms	remaining: 864ms
# 450:	learn: 0.2913047	total: 708ms	remaining: 862ms
# 451:	learn: 0.2912124	total: 709ms	remaining: 860ms
# 452:	learn: 0.2911985	total: 710ms	remaining: 857ms
# 453:	learn: 0.2910419	total: 711ms	remaining: 855ms
# 454:	learn: 0.2907297	total: 712ms	remaining: 853ms
# 455:	learn: 0.2906583	total: 713ms	remaining: 850ms
# 456:	learn: 0.2905371	total: 714ms	remaining: 848ms
# 457:	learn: 0.2903506	total: 715ms	remaining: 846ms
# 458:	learn: 0.2900588	total: 716ms	remaining: 844ms
# 459:	learn: 0.2897980	total: 717ms	remaining: 842ms
# 460:	learn: 0.2895638	total: 718ms	remaining: 840ms
# 461:	learn: 0.2894620	total: 719ms	remaining: 838ms
# 462:	learn: 0.2893259	total: 720ms	remaining: 836ms
# 463:	learn: 0.2892212	total: 722ms	remaining: 833ms
# 464:	learn: 0.2890953	total: 723ms	remaining: 831ms
# 465:	learn: 0.2889110	total: 724ms	remaining: 829ms
# 466:	learn: 0.2888270	total: 725ms	remaining: 827ms
# 467:	learn: 0.2886048	total: 726ms	remaining: 825ms
# 468:	learn: 0.2884337	total: 727ms	remaining: 823ms
# 469:	learn: 0.2882807	total: 728ms	remaining: 821ms
# 470:	learn: 0.2881861	total: 729ms	remaining: 819ms
# 471:	learn: 0.2880843	total: 730ms	remaining: 817ms
# 472:	learn: 0.2879964	total: 731ms	remaining: 814ms
# 473:	learn: 0.2879016	total: 732ms	remaining: 812ms
# 474:	learn: 0.2877837	total: 733ms	remaining: 810ms
# 475:	learn: 0.2875961	total: 734ms	remaining: 808ms
# 476:	learn: 0.2873824	total: 735ms	remaining: 806ms
# 477:	learn: 0.2873253	total: 736ms	remaining: 804ms
# 478:	learn: 0.2872130	total: 737ms	remaining: 802ms
# 479:	learn: 0.2872020	total: 738ms	remaining: 800ms
# 480:	learn: 0.2870749	total: 739ms	remaining: 798ms
# 481:	learn: 0.2869184	total: 740ms	remaining: 796ms
# 482:	learn: 0.2869051	total: 741ms	remaining: 793ms
# 483:	learn: 0.2865232	total: 742ms	remaining: 791ms
# 484:	learn: 0.2863903	total: 743ms	remaining: 789ms
# 485:	learn: 0.2863322	total: 744ms	remaining: 787ms
# 486:	learn: 0.2861515	total: 745ms	remaining: 785ms
# 487:	learn: 0.2860506	total: 746ms	remaining: 783ms
# 488:	learn: 0.2859932	total: 747ms	remaining: 781ms
# 489:	learn: 0.2857773	total: 749ms	remaining: 779ms
# 490:	learn: 0.2856001	total: 750ms	remaining: 777ms
# 491:	learn: 0.2853269	total: 751ms	remaining: 775ms
# 492:	learn: 0.2852585	total: 752ms	remaining: 774ms
# 493:	learn: 0.2851706	total: 754ms	remaining: 772ms
# 494:	learn: 0.2848798	total: 755ms	remaining: 770ms
# 495:	learn: 0.2845948	total: 756ms	remaining: 769ms
# 496:	learn: 0.2844485	total: 758ms	remaining: 767ms
# 497:	learn: 0.2843435	total: 759ms	remaining: 765ms
# 498:	learn: 0.2841396	total: 760ms	remaining: 763ms
# 499:	learn: 0.2839963	total: 761ms	remaining: 761ms
# 500:	learn: 0.2838915	total: 762ms	remaining: 759ms
# 501:	learn: 0.2836828	total: 764ms	remaining: 758ms
# 502:	learn: 0.2834128	total: 765ms	remaining: 756ms
# 503:	learn: 0.2831508	total: 766ms	remaining: 754ms
# 504:	learn: 0.2830937	total: 767ms	remaining: 752ms
# 505:	learn: 0.2829742	total: 768ms	remaining: 749ms
# 506:	learn: 0.2829005	total: 769ms	remaining: 747ms
# 507:	learn: 0.2827831	total: 770ms	remaining: 745ms
# 508:	learn: 0.2825507	total: 771ms	remaining: 743ms
# 509:	learn: 0.2822233	total: 772ms	remaining: 742ms
# 510:	learn: 0.2821068	total: 773ms	remaining: 740ms
# 511:	learn: 0.2820328	total: 774ms	remaining: 738ms
# 512:	learn: 0.2818520	total: 775ms	remaining: 736ms
# 513:	learn: 0.2816538	total: 776ms	remaining: 734ms
# 514:	learn: 0.2814916	total: 777ms	remaining: 732ms
# 515:	learn: 0.2813534	total: 778ms	remaining: 730ms
# 516:	learn: 0.2811897	total: 779ms	remaining: 728ms
# 517:	learn: 0.2810259	total: 780ms	remaining: 726ms
# 518:	learn: 0.2808441	total: 781ms	remaining: 724ms
# 519:	learn: 0.2804831	total: 782ms	remaining: 722ms
# 520:	learn: 0.2803145	total: 784ms	remaining: 720ms
# 521:	learn: 0.2802872	total: 785ms	remaining: 718ms
# 522:	learn: 0.2800868	total: 786ms	remaining: 716ms
# 523:	learn: 0.2799501	total: 787ms	remaining: 715ms
# 524:	learn: 0.2798232	total: 788ms	remaining: 713ms
# 525:	learn: 0.2796790	total: 789ms	remaining: 711ms
# 526:	learn: 0.2796292	total: 790ms	remaining: 709ms
# 527:	learn: 0.2795535	total: 791ms	remaining: 707ms
# 528:	learn: 0.2795015	total: 792ms	remaining: 705ms
# 529:	learn: 0.2793855	total: 793ms	remaining: 703ms
# 530:	learn: 0.2792725	total: 794ms	remaining: 701ms
# 531:	learn: 0.2789925	total: 795ms	remaining: 700ms
# 532:	learn: 0.2788297	total: 796ms	remaining: 698ms
# 533:	learn: 0.2786404	total: 797ms	remaining: 696ms
# 534:	learn: 0.2785495	total: 799ms	remaining: 694ms
# 535:	learn: 0.2783808	total: 800ms	remaining: 692ms
# 536:	learn: 0.2782732	total: 801ms	remaining: 690ms
# 537:	learn: 0.2781755	total: 802ms	remaining: 688ms
# 538:	learn: 0.2780623	total: 803ms	remaining: 687ms
# 539:	learn: 0.2779734	total: 804ms	remaining: 685ms
# 540:	learn: 0.2777852	total: 805ms	remaining: 683ms
# 541:	learn: 0.2776460	total: 806ms	remaining: 681ms
# 542:	learn: 0.2775375	total: 807ms	remaining: 679ms
# 543:	learn: 0.2775270	total: 808ms	remaining: 677ms
# 544:	learn: 0.2774932	total: 809ms	remaining: 675ms
# 545:	learn: 0.2773363	total: 810ms	remaining: 673ms
# 546:	learn: 0.2772262	total: 811ms	remaining: 672ms
# 547:	learn: 0.2770449	total: 812ms	remaining: 670ms
# 548:	learn: 0.2770286	total: 813ms	remaining: 668ms
# 549:	learn: 0.2769840	total: 814ms	remaining: 666ms
# 550:	learn: 0.2769244	total: 815ms	remaining: 664ms
# 551:	learn: 0.2766433	total: 816ms	remaining: 662ms
# 552:	learn: 0.2764763	total: 817ms	remaining: 660ms
# 553:	learn: 0.2764150	total: 818ms	remaining: 658ms
# 554:	learn: 0.2760964	total: 819ms	remaining: 657ms
# 555:	learn: 0.2760402	total: 820ms	remaining: 655ms
# 556:	learn: 0.2759402	total: 821ms	remaining: 653ms
# 557:	learn: 0.2757471	total: 822ms	remaining: 651ms
# 558:	learn: 0.2755368	total: 823ms	remaining: 649ms
# 559:	learn: 0.2753457	total: 824ms	remaining: 648ms
# 560:	learn: 0.2751454	total: 826ms	remaining: 646ms
# 561:	learn: 0.2750492	total: 827ms	remaining: 644ms
# 562:	learn: 0.2747186	total: 828ms	remaining: 643ms
# 563:	learn: 0.2745879	total: 829ms	remaining: 641ms
# 564:	learn: 0.2744241	total: 830ms	remaining: 639ms
# 565:	learn: 0.2742751	total: 831ms	remaining: 637ms
# 566:	learn: 0.2741441	total: 832ms	remaining: 636ms
# 567:	learn: 0.2739561	total: 833ms	remaining: 634ms
# 568:	learn: 0.2738927	total: 834ms	remaining: 632ms
# 569:	learn: 0.2738844	total: 835ms	remaining: 630ms
# 570:	learn: 0.2737857	total: 836ms	remaining: 628ms
# 571:	learn: 0.2737828	total: 836ms	remaining: 626ms
# 572:	learn: 0.2737764	total: 837ms	remaining: 624ms
# 573:	learn: 0.2737431	total: 838ms	remaining: 622ms
# 574:	learn: 0.2737167	total: 838ms	remaining: 620ms
# 575:	learn: 0.2735610	total: 840ms	remaining: 618ms
# 576:	learn: 0.2734135	total: 841ms	remaining: 616ms
# 577:	learn: 0.2733480	total: 842ms	remaining: 615ms
# 578:	learn: 0.2733031	total: 843ms	remaining: 613ms
# 579:	learn: 0.2731152	total: 844ms	remaining: 611ms
# 580:	learn: 0.2729505	total: 845ms	remaining: 610ms
# 581:	learn: 0.2729338	total: 846ms	remaining: 608ms
# 582:	learn: 0.2727412	total: 847ms	remaining: 606ms
# 583:	learn: 0.2725728	total: 849ms	remaining: 605ms
# 584:	learn: 0.2724652	total: 850ms	remaining: 603ms
# 585:	learn: 0.2724056	total: 851ms	remaining: 601ms
# 586:	learn: 0.2723132	total: 852ms	remaining: 600ms
# 587:	learn: 0.2722219	total: 853ms	remaining: 598ms
# 588:	learn: 0.2720845	total: 855ms	remaining: 596ms
# 589:	learn: 0.2719919	total: 856ms	remaining: 595ms
# 590:	learn: 0.2718494	total: 858ms	remaining: 593ms
# 591:	learn: 0.2717411	total: 859ms	remaining: 592ms
# 592:	learn: 0.2715362	total: 860ms	remaining: 590ms
# 593:	learn: 0.2714751	total: 861ms	remaining: 589ms
# 594:	learn: 0.2713778	total: 862ms	remaining: 587ms
# 595:	learn: 0.2713157	total: 864ms	remaining: 585ms
# 596:	learn: 0.2711926	total: 865ms	remaining: 584ms
# 597:	learn: 0.2710710	total: 866ms	remaining: 582ms
# 598:	learn: 0.2707937	total: 867ms	remaining: 581ms
# 599:	learn: 0.2707437	total: 868ms	remaining: 579ms
# 600:	learn: 0.2706816	total: 870ms	remaining: 577ms
# 601:	learn: 0.2705517	total: 871ms	remaining: 576ms
# 602:	learn: 0.2703887	total: 872ms	remaining: 574ms
# 603:	learn: 0.2702526	total: 873ms	remaining: 573ms
# 604:	learn: 0.2701392	total: 875ms	remaining: 571ms
# 605:	learn: 0.2700641	total: 876ms	remaining: 569ms
# 606:	learn: 0.2699101	total: 877ms	remaining: 568ms
# 607:	learn: 0.2697939	total: 878ms	remaining: 566ms
# 608:	learn: 0.2697029	total: 879ms	remaining: 565ms
# 609:	learn: 0.2695446	total: 881ms	remaining: 563ms
# 610:	learn: 0.2694273	total: 882ms	remaining: 561ms
# 611:	learn: 0.2693746	total: 883ms	remaining: 560ms
# 612:	learn: 0.2692476	total: 884ms	remaining: 558ms
# 613:	learn: 0.2691395	total: 885ms	remaining: 557ms
# 614:	learn: 0.2691275	total: 886ms	remaining: 555ms
# 615:	learn: 0.2689695	total: 887ms	remaining: 553ms
# 616:	learn: 0.2688712	total: 889ms	remaining: 552ms
# 617:	learn: 0.2686902	total: 890ms	remaining: 550ms
# 618:	learn: 0.2685000	total: 891ms	remaining: 548ms
# 619:	learn: 0.2684378	total: 892ms	remaining: 547ms
# 620:	learn: 0.2683964	total: 893ms	remaining: 545ms
# 621:	learn: 0.2682949	total: 895ms	remaining: 544ms
# 622:	learn: 0.2682056	total: 896ms	remaining: 542ms
# 623:	learn: 0.2680687	total: 897ms	remaining: 540ms
# 624:	learn: 0.2678877	total: 898ms	remaining: 539ms
# 625:	learn: 0.2678153	total: 899ms	remaining: 537ms
# 626:	learn: 0.2677482	total: 901ms	remaining: 536ms
# 627:	learn: 0.2675881	total: 902ms	remaining: 534ms
# 628:	learn: 0.2675779	total: 903ms	remaining: 532ms
# 629:	learn: 0.2674355	total: 904ms	remaining: 531ms
# 630:	learn: 0.2672659	total: 905ms	remaining: 529ms
# 631:	learn: 0.2671528	total: 906ms	remaining: 528ms
# 632:	learn: 0.2670248	total: 907ms	remaining: 526ms
# 633:	learn: 0.2668984	total: 908ms	remaining: 524ms
# 634:	learn: 0.2668630	total: 910ms	remaining: 523ms
# 635:	learn: 0.2668243	total: 911ms	remaining: 521ms
# 636:	learn: 0.2666984	total: 912ms	remaining: 520ms
# 637:	learn: 0.2664953	total: 913ms	remaining: 518ms
# 638:	learn: 0.2664830	total: 914ms	remaining: 516ms
# 639:	learn: 0.2663852	total: 915ms	remaining: 514ms
# 640:	learn: 0.2663214	total: 916ms	remaining: 513ms
# 641:	learn: 0.2661172	total: 917ms	remaining: 511ms
# 642:	learn: 0.2659580	total: 918ms	remaining: 510ms
# 643:	learn: 0.2657898	total: 919ms	remaining: 508ms
# 644:	learn: 0.2656415	total: 920ms	remaining: 506ms
# 645:	learn: 0.2655408	total: 921ms	remaining: 505ms
# 646:	learn: 0.2654472	total: 922ms	remaining: 503ms
# 647:	learn: 0.2653830	total: 924ms	remaining: 502ms
# 648:	learn: 0.2653544	total: 925ms	remaining: 500ms
# 649:	learn: 0.2651561	total: 926ms	remaining: 498ms
# 650:	learn: 0.2651294	total: 927ms	remaining: 497ms
# 651:	learn: 0.2650272	total: 928ms	remaining: 495ms
# 652:	learn: 0.2648289	total: 929ms	remaining: 494ms
# 653:	learn: 0.2646397	total: 930ms	remaining: 492ms
# 654:	learn: 0.2645555	total: 931ms	remaining: 490ms
# 655:	learn: 0.2644886	total: 932ms	remaining: 489ms
# 656:	learn: 0.2643325	total: 933ms	remaining: 487ms
# 657:	learn: 0.2641979	total: 934ms	remaining: 486ms
# 658:	learn: 0.2641110	total: 935ms	remaining: 484ms
# 659:	learn: 0.2639966	total: 937ms	remaining: 482ms
# 660:	learn: 0.2638560	total: 938ms	remaining: 481ms
# 661:	learn: 0.2637950	total: 939ms	remaining: 479ms
# 662:	learn: 0.2635745	total: 940ms	remaining: 478ms
# 663:	learn: 0.2633955	total: 941ms	remaining: 476ms
# 664:	learn: 0.2633289	total: 942ms	remaining: 474ms
# 665:	learn: 0.2632407	total: 943ms	remaining: 473ms
# 666:	learn: 0.2628989	total: 944ms	remaining: 471ms
# 667:	learn: 0.2627849	total: 946ms	remaining: 470ms
# 668:	learn: 0.2627580	total: 947ms	remaining: 468ms
# 669:	learn: 0.2627493	total: 947ms	remaining: 467ms
# 670:	learn: 0.2625771	total: 948ms	remaining: 465ms
# 671:	learn: 0.2625286	total: 949ms	remaining: 463ms
# 672:	learn: 0.2623108	total: 951ms	remaining: 462ms
# 673:	learn: 0.2621464	total: 952ms	remaining: 460ms
# 674:	learn: 0.2620528	total: 953ms	remaining: 459ms
# 675:	learn: 0.2619343	total: 954ms	remaining: 457ms
# 676:	learn: 0.2618715	total: 956ms	remaining: 456ms
# 677:	learn: 0.2617903	total: 957ms	remaining: 454ms
# 678:	learn: 0.2616414	total: 958ms	remaining: 453ms
# 679:	learn: 0.2615714	total: 959ms	remaining: 451ms
# 680:	learn: 0.2613384	total: 960ms	remaining: 450ms
# 681:	learn: 0.2612207	total: 961ms	remaining: 448ms
# 682:	learn: 0.2611655	total: 962ms	remaining: 446ms
# 683:	learn: 0.2611424	total: 963ms	remaining: 445ms
# 684:	learn: 0.2609129	total: 964ms	remaining: 443ms
# 685:	learn: 0.2608248	total: 965ms	remaining: 442ms
# 686:	learn: 0.2607539	total: 966ms	remaining: 440ms
# 687:	learn: 0.2605881	total: 967ms	remaining: 439ms
# 688:	learn: 0.2604945	total: 968ms	remaining: 437ms
# 689:	learn: 0.2603538	total: 969ms	remaining: 436ms
# 690:	learn: 0.2601888	total: 971ms	remaining: 434ms
# 691:	learn: 0.2600230	total: 972ms	remaining: 432ms
# 692:	learn: 0.2599317	total: 973ms	remaining: 431ms
# 693:	learn: 0.2598461	total: 974ms	remaining: 429ms
# 694:	learn: 0.2597169	total: 975ms	remaining: 428ms
# 695:	learn: 0.2596696	total: 976ms	remaining: 426ms
# 696:	learn: 0.2595348	total: 977ms	remaining: 425ms
# 697:	learn: 0.2594641	total: 978ms	remaining: 423ms
# 698:	learn: 0.2593100	total: 979ms	remaining: 422ms
# 699:	learn: 0.2592259	total: 980ms	remaining: 420ms
# 700:	learn: 0.2590057	total: 981ms	remaining: 419ms
# 701:	learn: 0.2588644	total: 982ms	remaining: 417ms
# 702:	learn: 0.2586694	total: 984ms	remaining: 416ms
# 703:	learn: 0.2585821	total: 985ms	remaining: 414ms
# 704:	learn: 0.2584748	total: 986ms	remaining: 413ms
# 705:	learn: 0.2584100	total: 987ms	remaining: 411ms
# 706:	learn: 0.2581573	total: 988ms	remaining: 409ms
# 707:	learn: 0.2581257	total: 989ms	remaining: 408ms
# 708:	learn: 0.2579806	total: 990ms	remaining: 406ms
# 709:	learn: 0.2579033	total: 991ms	remaining: 405ms
# 710:	learn: 0.2577256	total: 992ms	remaining: 403ms
# 711:	learn: 0.2576251	total: 993ms	remaining: 402ms
# 712:	learn: 0.2575644	total: 994ms	remaining: 400ms
# 713:	learn: 0.2575276	total: 995ms	remaining: 399ms
# 714:	learn: 0.2574276	total: 996ms	remaining: 397ms
# 715:	learn: 0.2571744	total: 998ms	remaining: 396ms
# 716:	learn: 0.2570284	total: 999ms	remaining: 394ms
# 717:	learn: 0.2568191	total: 1000ms	remaining: 393ms
# 718:	learn: 0.2567509	total: 1s	remaining: 391ms
# 719:	learn: 0.2566524	total: 1s	remaining: 390ms
# 720:	learn: 0.2564715	total: 1s	remaining: 388ms
# 721:	learn: 0.2563750	total: 1s	remaining: 387ms
# 722:	learn: 0.2562377	total: 1s	remaining: 385ms
# 723:	learn: 0.2559470	total: 1.01s	remaining: 384ms
# 724:	learn: 0.2557814	total: 1.01s	remaining: 382ms
# 725:	learn: 0.2556923	total: 1.01s	remaining: 380ms
# 726:	learn: 0.2556201	total: 1.01s	remaining: 379ms
# 727:	learn: 0.2555404	total: 1.01s	remaining: 377ms
# 728:	learn: 0.2551288	total: 1.01s	remaining: 376ms
# 729:	learn: 0.2550246	total: 1.01s	remaining: 374ms
# 730:	learn: 0.2548656	total: 1.01s	remaining: 373ms
# 731:	learn: 0.2546677	total: 1.01s	remaining: 371ms
# 732:	learn: 0.2546023	total: 1.01s	remaining: 370ms
# 733:	learn: 0.2544015	total: 1.02s	remaining: 369ms
# 734:	learn: 0.2542098	total: 1.02s	remaining: 367ms
# 735:	learn: 0.2541598	total: 1.02s	remaining: 366ms
# 736:	learn: 0.2539980	total: 1.02s	remaining: 364ms
# 737:	learn: 0.2538045	total: 1.02s	remaining: 363ms
# 738:	learn: 0.2536761	total: 1.02s	remaining: 361ms
# 739:	learn: 0.2535649	total: 1.02s	remaining: 360ms
# 740:	learn: 0.2533721	total: 1.02s	remaining: 358ms
# 741:	learn: 0.2531222	total: 1.02s	remaining: 357ms
# 742:	learn: 0.2529690	total: 1.03s	remaining: 355ms
# 743:	learn: 0.2528476	total: 1.03s	remaining: 354ms
# 744:	learn: 0.2527876	total: 1.03s	remaining: 352ms
# 745:	learn: 0.2527458	total: 1.03s	remaining: 351ms
# 746:	learn: 0.2526671	total: 1.03s	remaining: 349ms
# 747:	learn: 0.2525247	total: 1.03s	remaining: 348ms
# 748:	learn: 0.2522877	total: 1.03s	remaining: 347ms
# 749:	learn: 0.2521111	total: 1.03s	remaining: 345ms
# 750:	learn: 0.2519966	total: 1.04s	remaining: 344ms
# 751:	learn: 0.2518218	total: 1.04s	remaining: 342ms
# 752:	learn: 0.2516593	total: 1.04s	remaining: 341ms
# 753:	learn: 0.2514735	total: 1.04s	remaining: 339ms
# 754:	learn: 0.2512251	total: 1.04s	remaining: 338ms
# 755:	learn: 0.2510757	total: 1.04s	remaining: 337ms
# 756:	learn: 0.2509674	total: 1.04s	remaining: 335ms
# 757:	learn: 0.2508991	total: 1.04s	remaining: 334ms
# 758:	learn: 0.2507350	total: 1.05s	remaining: 332ms
# 759:	learn: 0.2506940	total: 1.05s	remaining: 331ms
# 760:	learn: 0.2506073	total: 1.05s	remaining: 329ms
# 761:	learn: 0.2504536	total: 1.05s	remaining: 328ms
# 762:	learn: 0.2502268	total: 1.05s	remaining: 326ms
# 763:	learn: 0.2500350	total: 1.05s	remaining: 325ms
# 764:	learn: 0.2497202	total: 1.05s	remaining: 323ms
# 765:	learn: 0.2496300	total: 1.05s	remaining: 322ms
# 766:	learn: 0.2494863	total: 1.05s	remaining: 320ms
# 767:	learn: 0.2494105	total: 1.05s	remaining: 319ms
# 768:	learn: 0.2492500	total: 1.06s	remaining: 317ms
# 769:	learn: 0.2490294	total: 1.06s	remaining: 316ms
# 770:	learn: 0.2489212	total: 1.06s	remaining: 315ms
# 771:	learn: 0.2487565	total: 1.06s	remaining: 313ms
# 772:	learn: 0.2486635	total: 1.06s	remaining: 312ms
# 773:	learn: 0.2486225	total: 1.06s	remaining: 310ms
# 774:	learn: 0.2485568	total: 1.06s	remaining: 309ms
# 775:	learn: 0.2484964	total: 1.06s	remaining: 307ms
# 776:	learn: 0.2484105	total: 1.06s	remaining: 306ms
# 777:	learn: 0.2483971	total: 1.07s	remaining: 304ms
# 778:	learn: 0.2483212	total: 1.07s	remaining: 303ms
# 779:	learn: 0.2480628	total: 1.07s	remaining: 301ms
# 780:	learn: 0.2479293	total: 1.07s	remaining: 300ms
# 781:	learn: 0.2478074	total: 1.07s	remaining: 298ms
# 782:	learn: 0.2476280	total: 1.07s	remaining: 297ms
# 783:	learn: 0.2475183	total: 1.07s	remaining: 296ms
# 784:	learn: 0.2474896	total: 1.07s	remaining: 294ms
# 785:	learn: 0.2473191	total: 1.07s	remaining: 293ms
# 786:	learn: 0.2471159	total: 1.07s	remaining: 291ms
# 787:	learn: 0.2469860	total: 1.08s	remaining: 290ms
# 788:	learn: 0.2468684	total: 1.08s	remaining: 288ms
# 789:	learn: 0.2467679	total: 1.08s	remaining: 287ms
# 790:	learn: 0.2467334	total: 1.08s	remaining: 285ms
# 791:	learn: 0.2466588	total: 1.08s	remaining: 284ms
# 792:	learn: 0.2464861	total: 1.08s	remaining: 282ms
# 793:	learn: 0.2464377	total: 1.08s	remaining: 281ms
# 794:	learn: 0.2463846	total: 1.08s	remaining: 280ms
# 795:	learn: 0.2462875	total: 1.08s	remaining: 278ms
# 796:	learn: 0.2460676	total: 1.09s	remaining: 277ms
# 797:	learn: 0.2459485	total: 1.09s	remaining: 275ms
# 798:	learn: 0.2457155	total: 1.09s	remaining: 274ms
# 799:	learn: 0.2455968	total: 1.09s	remaining: 272ms
# 800:	learn: 0.2455518	total: 1.09s	remaining: 271ms
# 801:	learn: 0.2455306	total: 1.09s	remaining: 270ms
# 802:	learn: 0.2454067	total: 1.09s	remaining: 268ms
# 803:	learn: 0.2453291	total: 1.09s	remaining: 267ms
# 804:	learn: 0.2452964	total: 1.09s	remaining: 265ms
# 805:	learn: 0.2451130	total: 1.1s	remaining: 264ms
# 806:	learn: 0.2450070	total: 1.1s	remaining: 262ms
# 807:	learn: 0.2448364	total: 1.1s	remaining: 261ms
# 808:	learn: 0.2446487	total: 1.1s	remaining: 260ms
# 809:	learn: 0.2445169	total: 1.1s	remaining: 258ms
# 810:	learn: 0.2443359	total: 1.1s	remaining: 257ms
# 811:	learn: 0.2441593	total: 1.1s	remaining: 255ms
# 812:	learn: 0.2438949	total: 1.1s	remaining: 254ms
# 813:	learn: 0.2436882	total: 1.1s	remaining: 252ms
# 814:	learn: 0.2435102	total: 1.1s	remaining: 251ms
# 815:	learn: 0.2434499	total: 1.11s	remaining: 250ms
# 816:	learn: 0.2433605	total: 1.11s	remaining: 248ms
# 817:	learn: 0.2433385	total: 1.11s	remaining: 247ms
# 818:	learn: 0.2431975	total: 1.11s	remaining: 245ms
# 819:	learn: 0.2430615	total: 1.11s	remaining: 244ms
# 820:	learn: 0.2430167	total: 1.11s	remaining: 243ms
# 821:	learn: 0.2428698	total: 1.11s	remaining: 241ms
# 822:	learn: 0.2427126	total: 1.11s	remaining: 240ms
# 823:	learn: 0.2426008	total: 1.11s	remaining: 238ms
# 824:	learn: 0.2423095	total: 1.12s	remaining: 237ms
# 825:	learn: 0.2421419	total: 1.12s	remaining: 235ms
# 826:	learn: 0.2421044	total: 1.12s	remaining: 234ms
# 827:	learn: 0.2420334	total: 1.12s	remaining: 233ms
# 828:	learn: 0.2420139	total: 1.12s	remaining: 231ms
# 829:	learn: 0.2419432	total: 1.12s	remaining: 230ms
# 830:	learn: 0.2418596	total: 1.12s	remaining: 228ms
# 831:	learn: 0.2417638	total: 1.12s	remaining: 227ms
# 832:	learn: 0.2417258	total: 1.13s	remaining: 226ms
# 833:	learn: 0.2416627	total: 1.13s	remaining: 224ms
# 834:	learn: 0.2415637	total: 1.13s	remaining: 223ms
# 835:	learn: 0.2414328	total: 1.13s	remaining: 221ms
# 836:	learn: 0.2412808	total: 1.13s	remaining: 220ms
# 837:	learn: 0.2412493	total: 1.13s	remaining: 219ms
# 838:	learn: 0.2411331	total: 1.13s	remaining: 217ms
# 839:	learn: 0.2410392	total: 1.13s	remaining: 216ms
# 840:	learn: 0.2409342	total: 1.14s	remaining: 215ms
# 841:	learn: 0.2408703	total: 1.14s	remaining: 213ms
# 842:	learn: 0.2406896	total: 1.14s	remaining: 212ms
# 843:	learn: 0.2406863	total: 1.14s	remaining: 210ms
# 844:	learn: 0.2405770	total: 1.14s	remaining: 209ms
# 845:	learn: 0.2402585	total: 1.14s	remaining: 208ms
# 846:	learn: 0.2400693	total: 1.14s	remaining: 206ms
# 847:	learn: 0.2398947	total: 1.14s	remaining: 205ms
# 848:	learn: 0.2398274	total: 1.14s	remaining: 204ms
# 849:	learn: 0.2396481	total: 1.15s	remaining: 202ms
# 850:	learn: 0.2395498	total: 1.15s	remaining: 201ms
# 851:	learn: 0.2393746	total: 1.15s	remaining: 199ms
# 852:	learn: 0.2391500	total: 1.15s	remaining: 198ms
# 853:	learn: 0.2390939	total: 1.15s	remaining: 197ms
# 854:	learn: 0.2389444	total: 1.15s	remaining: 195ms
# 855:	learn: 0.2389170	total: 1.15s	remaining: 194ms
# 856:	learn: 0.2387142	total: 1.15s	remaining: 192ms
# 857:	learn: 0.2385299	total: 1.15s	remaining: 191ms
# 858:	learn: 0.2384900	total: 1.16s	remaining: 190ms
# 859:	learn: 0.2383844	total: 1.16s	remaining: 188ms
# 860:	learn: 0.2383063	total: 1.16s	remaining: 187ms
# 861:	learn: 0.2381956	total: 1.16s	remaining: 185ms
# 862:	learn: 0.2379947	total: 1.16s	remaining: 184ms
# 863:	learn: 0.2378190	total: 1.16s	remaining: 183ms
# 864:	learn: 0.2376854	total: 1.16s	remaining: 181ms
# 865:	learn: 0.2375093	total: 1.16s	remaining: 180ms
# 866:	learn: 0.2373939	total: 1.16s	remaining: 179ms
# 867:	learn: 0.2373587	total: 1.17s	remaining: 177ms
# 868:	learn: 0.2372052	total: 1.17s	remaining: 176ms
# 869:	learn: 0.2370795	total: 1.17s	remaining: 174ms
# 870:	learn: 0.2370005	total: 1.17s	remaining: 173ms
# 871:	learn: 0.2369056	total: 1.17s	remaining: 172ms
# 872:	learn: 0.2367597	total: 1.17s	remaining: 170ms
# 873:	learn: 0.2366507	total: 1.17s	remaining: 169ms
# 874:	learn: 0.2364214	total: 1.17s	remaining: 168ms
# 875:	learn: 0.2362273	total: 1.17s	remaining: 166ms
# 876:	learn: 0.2359033	total: 1.17s	remaining: 165ms
# 877:	learn: 0.2356485	total: 1.18s	remaining: 163ms
# 878:	learn: 0.2355897	total: 1.18s	remaining: 162ms
# 879:	learn: 0.2354254	total: 1.18s	remaining: 161ms
# 880:	learn: 0.2353365	total: 1.18s	remaining: 159ms
# 881:	learn: 0.2352332	total: 1.18s	remaining: 158ms
# 882:	learn: 0.2352101	total: 1.18s	remaining: 157ms
# 883:	learn: 0.2351064	total: 1.18s	remaining: 155ms
# 884:	learn: 0.2350604	total: 1.18s	remaining: 154ms
# 885:	learn: 0.2349475	total: 1.18s	remaining: 152ms
# 886:	learn: 0.2348154	total: 1.19s	remaining: 151ms
# 887:	learn: 0.2347000	total: 1.19s	remaining: 150ms
# 888:	learn: 0.2346437	total: 1.19s	remaining: 148ms
# 889:	learn: 0.2344569	total: 1.19s	remaining: 147ms
# 890:	learn: 0.2343003	total: 1.19s	remaining: 146ms
# 891:	learn: 0.2342363	total: 1.19s	remaining: 144ms
# 892:	learn: 0.2341695	total: 1.19s	remaining: 143ms
# 893:	learn: 0.2340450	total: 1.19s	remaining: 142ms
# 894:	learn: 0.2338540	total: 1.19s	remaining: 140ms
# 895:	learn: 0.2336970	total: 1.2s	remaining: 139ms
# 896:	learn: 0.2334717	total: 1.2s	remaining: 138ms
# 897:	learn: 0.2333919	total: 1.2s	remaining: 136ms
# 898:	learn: 0.2332529	total: 1.2s	remaining: 135ms
# 899:	learn: 0.2330534	total: 1.2s	remaining: 134ms
# 900:	learn: 0.2328798	total: 1.2s	remaining: 132ms
# 901:	learn: 0.2327488	total: 1.2s	remaining: 131ms
# 902:	learn: 0.2326178	total: 1.21s	remaining: 130ms
# 903:	learn: 0.2323906	total: 1.21s	remaining: 128ms
# 904:	learn: 0.2322779	total: 1.21s	remaining: 127ms
# 905:	learn: 0.2322441	total: 1.21s	remaining: 126ms
# 906:	learn: 0.2320913	total: 1.21s	remaining: 124ms
# 907:	learn: 0.2319098	total: 1.21s	remaining: 123ms
# 908:	learn: 0.2317647	total: 1.21s	remaining: 122ms
# 909:	learn: 0.2317487	total: 1.22s	remaining: 120ms
# 910:	learn: 0.2313502	total: 1.22s	remaining: 119ms
# 911:	learn: 0.2312721	total: 1.22s	remaining: 118ms
# 912:	learn: 0.2311402	total: 1.22s	remaining: 116ms
# 913:	learn: 0.2310397	total: 1.22s	remaining: 115ms
# 914:	learn: 0.2308837	total: 1.22s	remaining: 114ms
# 915:	learn: 0.2307918	total: 1.22s	remaining: 112ms
# 916:	learn: 0.2306730	total: 1.22s	remaining: 111ms
# 917:	learn: 0.2306215	total: 1.23s	remaining: 110ms
# 918:	learn: 0.2304735	total: 1.23s	remaining: 108ms
# 919:	learn: 0.2303457	total: 1.23s	remaining: 107ms
# 920:	learn: 0.2302128	total: 1.23s	remaining: 106ms
# 921:	learn: 0.2300617	total: 1.23s	remaining: 104ms
# 922:	learn: 0.2300093	total: 1.23s	remaining: 103ms
# ...
# 701:	learn: 0.2879006	total: 790ms	remaining: 335ms
# 702:	learn: 0.2875541	total: 791ms	remaining: 334ms
# 703:	learn: 0.2874282	total: 792ms	remaining: 333ms
# 704:	learn: 0.2873612	total: 793ms	remaining: 332ms
# 705:	learn: 0.2873041	total: 794ms	remaining: 331ms
# 706:	learn: 0.2872114	total: 795ms	remaining: 330ms
# 707:	learn: 0.2871548	total: 796ms	remaining: 328ms
# 708:	learn: 0.2869580	total: 797ms	remaining: 327ms
# 709:	learn: 0.2868795	total: 799ms	remaining: 326ms
# 710:	learn: 0.2867359	total: 800ms	remaining: 325ms
# 711:	learn: 0.2866749	total: 801ms	remaining: 324ms
# 712:	learn: 0.2865603	total: 802ms	remaining: 323ms
# 713:	learn: 0.2865533	total: 803ms	remaining: 321ms
# 714:	learn: 0.2863543	total: 804ms	remaining: 320ms
# 715:	learn: 0.2862406	total: 805ms	remaining: 319ms
# 716:	learn: 0.2861044	total: 806ms	remaining: 318ms
# 717:	learn: 0.2859354	total: 807ms	remaining: 317ms
# 718:	learn: 0.2858698	total: 808ms	remaining: 316ms
# 719:	learn: 0.2857739	total: 809ms	remaining: 315ms
# 720:	learn: 0.2855619	total: 810ms	remaining: 314ms
# 721:	learn: 0.2855149	total: 811ms	remaining: 312ms
# 722:	learn: 0.2854305	total: 812ms	remaining: 311ms
# 723:	learn: 0.2853251	total: 814ms	remaining: 310ms
# 724:	learn: 0.2852329	total: 816ms	remaining: 310ms
# 725:	learn: 0.2851443	total: 817ms	remaining: 308ms
# 726:	learn: 0.2848847	total: 818ms	remaining: 307ms
# 727:	learn: 0.2848334	total: 820ms	remaining: 306ms
# 728:	learn: 0.2847217	total: 821ms	remaining: 305ms
# 729:	learn: 0.2846403	total: 823ms	remaining: 304ms
# 730:	learn: 0.2845227	total: 824ms	remaining: 303ms
# 731:	learn: 0.2844041	total: 826ms	remaining: 302ms
# 732:	learn: 0.2843262	total: 827ms	remaining: 301ms
# 733:	learn: 0.2842661	total: 828ms	remaining: 300ms
# 734:	learn: 0.2840790	total: 830ms	remaining: 299ms
# 735:	learn: 0.2839715	total: 831ms	remaining: 298ms
# 736:	learn: 0.2838564	total: 832ms	remaining: 297ms
# 737:	learn: 0.2836387	total: 833ms	remaining: 296ms
# 738:	learn: 0.2834485	total: 834ms	remaining: 295ms
# 739:	learn: 0.2832770	total: 835ms	remaining: 294ms
# 740:	learn: 0.2831471	total: 836ms	remaining: 292ms
# 741:	learn: 0.2830581	total: 838ms	remaining: 291ms
# 742:	learn: 0.2829893	total: 839ms	remaining: 290ms
# 743:	learn: 0.2829462	total: 840ms	remaining: 289ms
# 744:	learn: 0.2828959	total: 841ms	remaining: 288ms
# 745:	learn: 0.2828175	total: 842ms	remaining: 287ms
# 746:	learn: 0.2827353	total: 843ms	remaining: 286ms
# 747:	learn: 0.2826596	total: 844ms	remaining: 284ms
# 748:	learn: 0.2824571	total: 845ms	remaining: 283ms
# 749:	learn: 0.2822426	total: 847ms	remaining: 282ms
# 750:	learn: 0.2819998	total: 848ms	remaining: 281ms
# 751:	learn: 0.2818924	total: 849ms	remaining: 280ms
# 752:	learn: 0.2817835	total: 850ms	remaining: 279ms
# 753:	learn: 0.2817091	total: 851ms	remaining: 278ms
# 754:	learn: 0.2816008	total: 852ms	remaining: 276ms
# 755:	learn: 0.2815398	total: 853ms	remaining: 275ms
# 756:	learn: 0.2813368	total: 854ms	remaining: 274ms
# 757:	learn: 0.2813054	total: 855ms	remaining: 273ms
# 758:	learn: 0.2811147	total: 856ms	remaining: 272ms
# 759:	learn: 0.2810125	total: 857ms	remaining: 271ms
# 760:	learn: 0.2807730	total: 859ms	remaining: 270ms
# 761:	learn: 0.2806183	total: 860ms	remaining: 268ms
# 762:	learn: 0.2805500	total: 861ms	remaining: 267ms
# 763:	learn: 0.2804019	total: 862ms	remaining: 266ms
# 764:	learn: 0.2803600	total: 863ms	remaining: 265ms
# 765:	learn: 0.2802171	total: 864ms	remaining: 264ms
# 766:	learn: 0.2801026	total: 865ms	remaining: 263ms
# 767:	learn: 0.2799640	total: 866ms	remaining: 262ms
# 768:	learn: 0.2797337	total: 867ms	remaining: 260ms
# 769:	learn: 0.2795687	total: 868ms	remaining: 259ms
# 770:	learn: 0.2793717	total: 869ms	remaining: 258ms
# 771:	learn: 0.2791305	total: 870ms	remaining: 257ms
# 772:	learn: 0.2790669	total: 871ms	remaining: 256ms
# 773:	learn: 0.2789361	total: 872ms	remaining: 255ms
# 774:	learn: 0.2788200	total: 874ms	remaining: 254ms
# 775:	learn: 0.2787140	total: 875ms	remaining: 252ms
# 776:	learn: 0.2786085	total: 876ms	remaining: 251ms
# 777:	learn: 0.2785076	total: 877ms	remaining: 250ms
# 778:	learn: 0.2784212	total: 878ms	remaining: 249ms
# 779:	learn: 0.2781982	total: 879ms	remaining: 248ms
# 780:	learn: 0.2779387	total: 880ms	remaining: 247ms
# 781:	learn: 0.2778627	total: 881ms	remaining: 246ms
# 782:	learn: 0.2775292	total: 882ms	remaining: 244ms
# 783:	learn: 0.2773341	total: 883ms	remaining: 243ms
# 784:	learn: 0.2772910	total: 884ms	remaining: 242ms
# 785:	learn: 0.2772225	total: 885ms	remaining: 241ms
# 786:	learn: 0.2771997	total: 886ms	remaining: 240ms
# 787:	learn: 0.2770498	total: 888ms	remaining: 239ms
# 788:	learn: 0.2770021	total: 889ms	remaining: 238ms
# 789:	learn: 0.2768778	total: 890ms	remaining: 236ms
# 790:	learn: 0.2766980	total: 891ms	remaining: 235ms
# 791:	learn: 0.2765805	total: 892ms	remaining: 234ms
# 792:	learn: 0.2764227	total: 893ms	remaining: 233ms
# 793:	learn: 0.2762402	total: 894ms	remaining: 232ms
# 794:	learn: 0.2761577	total: 895ms	remaining: 231ms
# 795:	learn: 0.2761343	total: 896ms	remaining: 230ms
# 796:	learn: 0.2760725	total: 897ms	remaining: 228ms
# 797:	learn: 0.2759986	total: 898ms	remaining: 227ms
# 798:	learn: 0.2759539	total: 899ms	remaining: 226ms
# 799:	learn: 0.2758543	total: 900ms	remaining: 225ms
# 800:	learn: 0.2756390	total: 901ms	remaining: 224ms
# 801:	learn: 0.2755203	total: 902ms	remaining: 223ms
# 802:	learn: 0.2753195	total: 904ms	remaining: 222ms
# 803:	learn: 0.2752500	total: 905ms	remaining: 221ms
# 804:	learn: 0.2750348	total: 906ms	remaining: 219ms
# 805:	learn: 0.2748967	total: 907ms	remaining: 218ms
# 806:	learn: 0.2747339	total: 908ms	remaining: 217ms
# 807:	learn: 0.2745800	total: 909ms	remaining: 216ms
# 808:	learn: 0.2743992	total: 910ms	remaining: 215ms
# 809:	learn: 0.2742530	total: 911ms	remaining: 214ms
# 810:	learn: 0.2738793	total: 912ms	remaining: 213ms
# 811:	learn: 0.2738637	total: 913ms	remaining: 211ms
# 812:	learn: 0.2735662	total: 914ms	remaining: 210ms
# 813:	learn: 0.2732897	total: 915ms	remaining: 209ms
# 814:	learn: 0.2732112	total: 916ms	remaining: 208ms
# 815:	learn: 0.2731731	total: 918ms	remaining: 207ms
# 816:	learn: 0.2730058	total: 919ms	remaining: 206ms
# 817:	learn: 0.2729857	total: 920ms	remaining: 205ms
# 818:	learn: 0.2726881	total: 921ms	remaining: 204ms
# 819:	learn: 0.2725572	total: 922ms	remaining: 202ms
# 820:	learn: 0.2724899	total: 923ms	remaining: 201ms
# 821:	learn: 0.2724753	total: 924ms	remaining: 200ms
# 822:	learn: 0.2724538	total: 925ms	remaining: 199ms
# 823:	learn: 0.2722989	total: 926ms	remaining: 198ms
# 824:	learn: 0.2721260	total: 927ms	remaining: 197ms
# 825:	learn: 0.2720698	total: 928ms	remaining: 195ms
# 826:	learn: 0.2720167	total: 929ms	remaining: 194ms
# 827:	learn: 0.2719527	total: 930ms	remaining: 193ms
# 828:	learn: 0.2718132	total: 931ms	remaining: 192ms
# 829:	learn: 0.2717227	total: 932ms	remaining: 191ms
# 830:	learn: 0.2715446	total: 934ms	remaining: 190ms
# 831:	learn: 0.2712558	total: 935ms	remaining: 189ms
# 832:	learn: 0.2710664	total: 936ms	remaining: 188ms
# 833:	learn: 0.2710050	total: 937ms	remaining: 186ms
# 834:	learn: 0.2707714	total: 938ms	remaining: 185ms
# 835:	learn: 0.2705595	total: 939ms	remaining: 184ms
# 836:	learn: 0.2705130	total: 940ms	remaining: 183ms
# 837:	learn: 0.2704491	total: 941ms	remaining: 182ms
# 838:	learn: 0.2703404	total: 942ms	remaining: 181ms
# 839:	learn: 0.2701341	total: 943ms	remaining: 180ms
# 840:	learn: 0.2699012	total: 944ms	remaining: 178ms
# 841:	learn: 0.2697901	total: 945ms	remaining: 177ms
# 842:	learn: 0.2697523	total: 946ms	remaining: 176ms
# 843:	learn: 0.2695152	total: 947ms	remaining: 175ms
# 844:	learn: 0.2694292	total: 948ms	remaining: 174ms
# 845:	learn: 0.2692494	total: 949ms	remaining: 173ms
# 846:	learn: 0.2691653	total: 950ms	remaining: 172ms
# 847:	learn: 0.2689055	total: 951ms	remaining: 171ms
# 848:	learn: 0.2687525	total: 952ms	remaining: 169ms
# 849:	learn: 0.2684902	total: 954ms	remaining: 168ms
# 850:	learn: 0.2683601	total: 955ms	remaining: 167ms
# 851:	learn: 0.2682907	total: 956ms	remaining: 166ms
# 852:	learn: 0.2682024	total: 957ms	remaining: 165ms
# 853:	learn: 0.2680706	total: 958ms	remaining: 164ms
# 854:	learn: 0.2680370	total: 959ms	remaining: 163ms
# 855:	learn: 0.2677745	total: 960ms	remaining: 161ms
# 856:	learn: 0.2676921	total: 961ms	remaining: 160ms
# 857:	learn: 0.2675330	total: 962ms	remaining: 159ms
# 858:	learn: 0.2674718	total: 963ms	remaining: 158ms
# 859:	learn: 0.2673975	total: 964ms	remaining: 157ms
# 860:	learn: 0.2671942	total: 965ms	remaining: 156ms
# 861:	learn: 0.2671170	total: 966ms	remaining: 155ms
# 862:	learn: 0.2670050	total: 968ms	remaining: 154ms
# 863:	learn: 0.2667091	total: 969ms	remaining: 152ms
# 864:	learn: 0.2665806	total: 970ms	remaining: 151ms
# 865:	learn: 0.2663707	total: 971ms	remaining: 150ms
# 866:	learn: 0.2661744	total: 972ms	remaining: 149ms
# 867:	learn: 0.2658307	total: 973ms	remaining: 148ms
# 868:	learn: 0.2656907	total: 974ms	remaining: 147ms
# 869:	learn: 0.2655668	total: 975ms	remaining: 146ms
# 870:	learn: 0.2654370	total: 976ms	remaining: 145ms
# 871:	learn: 0.2651729	total: 977ms	remaining: 143ms
# 872:	learn: 0.2650358	total: 978ms	remaining: 142ms
# 873:	learn: 0.2649904	total: 979ms	remaining: 141ms
# 874:	learn: 0.2648583	total: 980ms	remaining: 140ms
# 875:	learn: 0.2647956	total: 981ms	remaining: 139ms
# 876:	learn: 0.2646713	total: 982ms	remaining: 138ms
# 877:	learn: 0.2645564	total: 983ms	remaining: 137ms
# 878:	learn: 0.2644539	total: 984ms	remaining: 135ms
# 879:	learn: 0.2643767	total: 985ms	remaining: 134ms
# 880:	learn: 0.2642899	total: 986ms	remaining: 133ms
# 881:	learn: 0.2642379	total: 987ms	remaining: 132ms
# 882:	learn: 0.2641061	total: 988ms	remaining: 131ms
# 883:	learn: 0.2639867	total: 990ms	remaining: 130ms
# 884:	learn: 0.2637994	total: 991ms	remaining: 129ms
# 885:	learn: 0.2637070	total: 992ms	remaining: 128ms
# 886:	learn: 0.2635766	total: 993ms	remaining: 126ms
# 887:	learn: 0.2634078	total: 994ms	remaining: 125ms
# 888:	learn: 0.2630710	total: 995ms	remaining: 124ms
# 889:	learn: 0.2629329	total: 996ms	remaining: 123ms
# 890:	learn: 0.2627645	total: 997ms	remaining: 122ms
# 891:	learn: 0.2623560	total: 998ms	remaining: 121ms
# 892:	learn: 0.2622197	total: 999ms	remaining: 120ms
# 893:	learn: 0.2621702	total: 1s	remaining: 119ms
# 894:	learn: 0.2619083	total: 1s	remaining: 117ms
# 895:	learn: 0.2617486	total: 1s	remaining: 116ms
# 896:	learn: 0.2616822	total: 1s	remaining: 115ms
# 897:	learn: 0.2614630	total: 1s	remaining: 114ms
# 898:	learn: 0.2614122	total: 1s	remaining: 113ms
# 899:	learn: 0.2613363	total: 1.01s	remaining: 112ms
# 900:	learn: 0.2611625	total: 1.01s	remaining: 111ms
# 901:	learn: 0.2610566	total: 1.01s	remaining: 110ms
# 902:	learn: 0.2608765	total: 1.01s	remaining: 109ms
# 903:	learn: 0.2607020	total: 1.01s	remaining: 107ms
# 904:	learn: 0.2606574	total: 1.01s	remaining: 106ms
# 905:	learn: 0.2605492	total: 1.01s	remaining: 105ms
# 906:	learn: 0.2603357	total: 1.01s	remaining: 104ms
# 907:	learn: 0.2602494	total: 1.01s	remaining: 103ms
# 908:	learn: 0.2601571	total: 1.02s	remaining: 102ms
# 909:	learn: 0.2600430	total: 1.02s	remaining: 101ms
# 910:	learn: 0.2598180	total: 1.02s	remaining: 99.6ms
# 911:	learn: 0.2596993	total: 1.02s	remaining: 98.5ms
# 912:	learn: 0.2594967	total: 1.02s	remaining: 97.4ms
# 913:	learn: 0.2592450	total: 1.02s	remaining: 96.2ms
# 914:	learn: 0.2590811	total: 1.02s	remaining: 95.1ms
# 915:	learn: 0.2589220	total: 1.02s	remaining: 94ms
# 916:	learn: 0.2588398	total: 1.03s	remaining: 92.9ms
# 917:	learn: 0.2587244	total: 1.03s	remaining: 91.8ms
# 918:	learn: 0.2585033	total: 1.03s	remaining: 90.7ms
# 919:	learn: 0.2584129	total: 1.03s	remaining: 89.6ms
# 920:	learn: 0.2583053	total: 1.03s	remaining: 88.4ms
# 921:	learn: 0.2580748	total: 1.03s	remaining: 87.3ms
# 922:	learn: 0.2578209	total: 1.03s	remaining: 86.2ms
# 923:	learn: 0.2577125	total: 1.03s	remaining: 85.1ms
# 924:	learn: 0.2576082	total: 1.03s	remaining: 83.9ms
# 925:	learn: 0.2575392	total: 1.04s	remaining: 82.8ms
# 926:	learn: 0.2574001	total: 1.04s	remaining: 81.7ms
# 927:	learn: 0.2573420	total: 1.04s	remaining: 80.6ms
# 928:	learn: 0.2572156	total: 1.04s	remaining: 79.4ms
# 929:	learn: 0.2571459	total: 1.04s	remaining: 78.3ms
# 930:	learn: 0.2570807	total: 1.04s	remaining: 77.2ms
# 931:	learn: 0.2570117	total: 1.04s	remaining: 76.1ms
# 932:	learn: 0.2568931	total: 1.04s	remaining: 74.9ms
# 933:	learn: 0.2567877	total: 1.04s	remaining: 73.8ms
# 934:	learn: 0.2565823	total: 1.04s	remaining: 72.7ms
# 935:	learn: 0.2564549	total: 1.05s	remaining: 71.6ms
# 936:	learn: 0.2563429	total: 1.05s	remaining: 70.5ms
# 937:	learn: 0.2562683	total: 1.05s	remaining: 69.3ms
# 938:	learn: 0.2560084	total: 1.05s	remaining: 68.2ms
# 939:	learn: 0.2559510	total: 1.05s	remaining: 67.1ms
# 940:	learn: 0.2557881	total: 1.05s	remaining: 66ms
# 941:	learn: 0.2556791	total: 1.05s	remaining: 64.8ms
# 942:	learn: 0.2555061	total: 1.05s	remaining: 63.7ms
# 943:	learn: 0.2553946	total: 1.05s	remaining: 62.6ms
# 944:	learn: 0.2551057	total: 1.06s	remaining: 61.5ms
# 945:	learn: 0.2550033	total: 1.06s	remaining: 60.4ms
# 946:	learn: 0.2549210	total: 1.06s	remaining: 59.2ms
# 947:	learn: 0.2548279	total: 1.06s	remaining: 58.1ms
# 948:	learn: 0.2546973	total: 1.06s	remaining: 57ms
# 949:	learn: 0.2545613	total: 1.06s	remaining: 55.9ms
# 950:	learn: 0.2543664	total: 1.06s	remaining: 54.8ms
# 951:	learn: 0.2542400	total: 1.06s	remaining: 53.6ms
# 952:	learn: 0.2541024	total: 1.06s	remaining: 52.5ms
# 953:	learn: 0.2540113	total: 1.06s	remaining: 51.4ms
# 954:	learn: 0.2538711	total: 1.07s	remaining: 50.3ms
# 955:	learn: 0.2538111	total: 1.07s	remaining: 49.2ms
# 956:	learn: 0.2535217	total: 1.07s	remaining: 48ms
# 957:	learn: 0.2534513	total: 1.07s	remaining: 46.9ms
# 958:	learn: 0.2534063	total: 1.07s	remaining: 45.8ms
# 959:	learn: 0.2531553	total: 1.07s	remaining: 44.7ms
# 960:	learn: 0.2530905	total: 1.07s	remaining: 43.6ms
# 961:	learn: 0.2529667	total: 1.07s	remaining: 42.4ms
# 962:	learn: 0.2528879	total: 1.07s	remaining: 41.3ms
# 963:	learn: 0.2527820	total: 1.08s	remaining: 40.2ms
# 964:	learn: 0.2526543	total: 1.08s	remaining: 39.1ms
# 965:	learn: 0.2525587	total: 1.08s	remaining: 38ms
# 966:	learn: 0.2524315	total: 1.08s	remaining: 36.8ms
# 967:	learn: 0.2522056	total: 1.08s	remaining: 35.7ms
# 968:	learn: 0.2521500	total: 1.08s	remaining: 34.6ms
# 969:	learn: 0.2518540	total: 1.08s	remaining: 33.5ms
# 970:	learn: 0.2516816	total: 1.08s	remaining: 32.4ms
# 971:	learn: 0.2515683	total: 1.08s	remaining: 31.2ms
# 972:	learn: 0.2513571	total: 1.08s	remaining: 30.1ms
# 973:	learn: 0.2513160	total: 1.09s	remaining: 29ms
# 974:	learn: 0.2511086	total: 1.09s	remaining: 27.9ms
# 975:	learn: 0.2509188	total: 1.09s	remaining: 26.8ms
# 976:	learn: 0.2507934	total: 1.09s	remaining: 25.7ms
# 977:	learn: 0.2506073	total: 1.09s	remaining: 24.5ms
# 978:	learn: 0.2504236	total: 1.09s	remaining: 23.4ms
# 979:	learn: 0.2502241	total: 1.09s	remaining: 22.3ms
# 980:	learn: 0.2501372	total: 1.09s	remaining: 21.2ms
# 981:	learn: 0.2500945	total: 1.09s	remaining: 20.1ms
# 982:	learn: 0.2499606	total: 1.1s	remaining: 19ms
# 983:	learn: 0.2498605	total: 1.1s	remaining: 17.8ms
# 984:	learn: 0.2497973	total: 1.1s	remaining: 16.7ms
# 985:	learn: 0.2496701	total: 1.1s	remaining: 15.6ms
# 986:	learn: 0.2496223	total: 1.1s	remaining: 14.5ms
# 987:	learn: 0.2494697	total: 1.1s	remaining: 13.4ms
# 988:	learn: 0.2492557	total: 1.1s	remaining: 12.3ms
# 989:	learn: 0.2491489	total: 1.1s	remaining: 11.1ms
# 990:	learn: 0.2489995	total: 1.1s	remaining: 10ms
# 991:	learn: 0.2489068	total: 1.11s	remaining: 8.92ms
# 992:	learn: 0.2487814	total: 1.11s	remaining: 7.8ms
# 993:	learn: 0.2487155	total: 1.11s	remaining: 6.69ms
# 994:	learn: 0.2485461	total: 1.11s	remaining: 5.57ms
# 995:	learn: 0.2483557	total: 1.11s	remaining: 4.46ms
# 996:	learn: 0.2482135	total: 1.11s	remaining: 3.34ms
# 997:	learn: 0.2480934	total: 1.11s	remaining: 2.23ms
# 998:	learn: 0.2480278	total: 1.11s	remaining: 1.11ms
# 999:	learn: 0.2479338	total: 1.11s	remaining: 0us
# CatBoostClassifier 0.8192090395480226
# XGBClassifier 0.8361581920903954
# RandomForestClassifier 0.8418079096045198
# AdaBoostClassifier 0.7740112994350282
# GradientBoostingClassifier 0.8135593220338984
# GaussianNB 0.807909604519774
# LinearDiscriminantAnalysis 0.8305084745762712
# QuadraticDiscriminantAnalysis 0.7853107344632768
# LogisticRegression 0.8192090395480226

# %% [markdown]
# ## Etape 5 : Evaluation

# %% [markdown]
# L'objectif de cette étape va être d'évaluer notre modèle et de l'optimiser un maximum c'est à dire de choisir les meilleurs valeurs pour nos hyperparamètres (les hyperparamètres sont des paramètres que l'on choisit avant d'entraîner un modèle de machine learning, et qui affectent le processus d'apprentissage et la performance du modèle). Ces paramètres sont essentiels car leur optimisation permet d'obtenir les meilleurs paramètres pour un modèle d'apprentissage automatique et donc d'obtenir des prédictions plus précises et plus fiables.

# %%
from sklearn.model_selection import KFold

kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# Étape de modélisation : Tester différents algorithmes
random_state = 2
classifiers = []
classifiers.append(SVC(random_state=random_state))
classifiers.append(DecisionTreeClassifier(random_state=random_state))
classifiers.append(AdaBoostClassifier(DecisionTreeClassifier(random_state=random_state),random_state=random_state,learning_rate=0.1))
classifiers.append(RandomForestClassifier(random_state=random_state))
classifiers.append(ExtraTreesClassifier(random_state=random_state))
classifiers.append(GradientBoostingClassifier(random_state=random_state))
classifiers.append(MLPClassifier(random_state=random_state))
classifiers.append(KNeighborsClassifier())
classifiers.append(LogisticRegression(random_state=random_state))
classifiers.append(LinearDiscriminantAnalysis())

cv_results = []
for classifier in classifiers :
    cv_results.append(cross_val_score(classifier, X_train, y=Y_train, scoring="accuracy", cv=kfold, n_jobs=4))

cv_means = []
cv_std = []
for cv_result in cv_results:
    cv_means.append(cv_result.mean())
    cv_std.append(cv_result.std())

cv_res = pd.DataFrame({
    "Accuracy (Précision) Moyenne": cv_means,
    "CrossValerrors": cv_std,
    "Modèles": [
        "SVC", "DecisionTree", "AdaBoost", "RandomForest", "ExtraTrees",
        "GradientBoosting", "MultipleLayerPerceptron", "KNeighboors",
        "LogisticRegression", "LinearDiscriminantAnalysis"
    ]
})

g = sns.barplot(
    "Accuracy (Précision) Moyenne", "Modèles", data=cv_res, palette="Set3",
    orient="h", **{'xerr': cv_std}
)
g.set_xlabel("Accuracy (Précision) Moyenne")
g = g.set_title("Scores de validation croisée")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Définir les modèles et leurs noms
classifiers = [SVC(random_state=random_state),
               DecisionTreeClassifier(random_state=random_state),
               AdaBoostClassifier(DecisionTreeClassifier(random_state=random_state), random_state=random_state, learning_rate=0.1),
               RandomForestClassifier(random_state=random_state),
               ExtraTreesClassifier(random_state=random_state),
               GradientBoostingClassifier(random_state=random_state),
               MLPClassifier(random_state=random_state),
               KNeighborsClassifier(),
               LogisticRegression(random_state=random_state),
               LinearDiscriminantAnalysis()]

model_names = ["SVC", "DecisionTree", "AdaBoost", "RandomForest", "ExtraTrees",
               "GradientBoosting", "MultipleLayerPerceptron", "KNeighboors",
               "LogisticRegression", "LinearDiscriminantAnalysis"]

# Calculer la performance de chaque modèle
performance = []
for classifier in classifiers:
    cv_results = cross_val_score(classifier, X_train, y=Y_train, scoring="accuracy", cv=kfold, n_jobs=4)
    performance.append(cv_results.mean())

# Créer un graphique
plt.figure(figsize=(10, 6))
sns.barplot(x=model_names, y=performance, palette="Set3")
plt.xticks(rotation=90)
plt.xlabel("Modèles")
plt.ylabel("Accuracy")
plt.title("Performance de chaque modèle")

# Ajouter les légendes correspondant à la valeur de chaque modèle
for i, v in enumerate(performance):
    plt.text(i, v, "{:.2f}".format(v), color='black', ha='center', fontweight='bold')

plt.show()

# %% [markdown]
# L'avantage de cette deuxième option réside dans sa méthode de calcul. En effet, ici pour chaque split une précision sera calculée et la précision du modèle correspondra à la moyenne des précisions du modèle sur chacune des données splitées. Cela permet de nous rassurer sur la performance du modèle, de limiter l'overfitting et d'annoncer que la random forest semble être le modèle le plus précis avec 84% de précision. Nous pouvons toutefois l'améliorer en modifiant ses hyperparamètres.

# %% [markdown]
# Je me suis permis d'ajouter ce tableau qui contient l'importance de chaque feature dans le modèle de forêt aléatoire (random_forest) pour voir le poids de chaque feature dans le modèle.

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42)

# entraîner le modèle sur les données d'entraînement
random_forest.fit(X_train, Y_train)
importances = pd.DataFrame({'feature': X_train.columns, 'importance': np.round(random_forest.feature_importances_, 3)})
importances = importances.sort_values('importance', ascending= False).set_index('feature')

importances.head(15)
# Out:
#              importance
# feature
# Sex               0.261
# Title             0.258
# Fare              0.136
# Pclass            0.103
# relatives         0.068
# Age               0.065
# PassengerId       0.049
# SibSp             0.031
# Embarked          0.015
# Parch             0.013

# %%
from sklearn.model_selection import GridSearchCV

# Définir les hyperparamètres à tester pour la Random Forest
rf_param_grid = {
    'n_estimators': [100, 300, 500, 800, 1200],
    'max_depth': [5, 8, 15, 25, 30],
    'min_samples_split': [2, 5, 10, 15, 100],
    'min_samples_leaf': [1, 2, 5, 10]
}

# Instancier la Random Forest
rf = RandomForestClassifier()

# Recherche par grille pour optimiser les hyperparamètres de la Random Forest
rf_grid_search = GridSearchCV(estimator = rf, param_grid = rf_param_grid, 
                          cv = 5, n_jobs = -1, verbose = 2)

# Entraîner la Random Forest avec les hyperparamètres optimisés
rf_grid_search.fit(x_train, y_train)

# Afficher les hyperparamètres optimisés
print("Meilleurs hyperparamètres pour la Random Forest: ", rf_grid_search.best_params_)

# Afficher la précision de la Random Forest avec les hyperparamètres optimisés
y_pred = rf_grid_search.predict(x_val)
acc = accuracy_score(y_val, y_pred)
print("Précision de la Random Forest avec les hyperparamètres optimisés: ", acc)
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# Meilleurs hyperparamètres pour la Random Forest:  {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 800}
# Précision de la Random Forest avec les hyperparamètres optimisés:  0.8608247422680413

# %% [markdown]
# Le modèle le plus performant que nous pouvons obtenir se base sur la Random Forest est à une précision de 91,75%. Les meilleurs hyperparamètres sont : une max_depth de 30, un min_samples_leaf de 2, un min_samples_split de 2 et un n_estimators de 100. Voilà le modèle le plus performant que j'ai pu obtenir.
